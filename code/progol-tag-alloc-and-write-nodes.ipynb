# %% [markdown]
# # Prolog Experiment: Tag the memory allocation and write nodes.

# %%
import pandas as pd
import tempfile
import subprocess
import graph_visualisation

# %% [markdown]
# *Idea:* in [previous experiments](./joern-ey-into-progol.ipynb) we've only tagged the memory write as a bug. This makes sense, since this is the spot where the program will crash. However, the memory allocation is also pretty important, since this is where the mistake lies. In this notebook we tag both nodes as buggy, like:
#
# `bug(MemoryAllocNode, MemoryWriteNode).`

# %% [markdown]
# This also has the potential to solve some complexity issues. Previously we've gotten rules which navigate across to the referenced pointer, but are unable to move up the ast edges to the memory allocation node. E.g.

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ast(A,D), ast(A,E), ref(E,F), sizeOf(C), ancestor(D,B), ast(C,B), ast(D,C)."
))

# %% [markdown]
# We believe the memory allocation is a parent of `F`, and so we want it to find a rule like:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot("""
bug(A) :- writeToPointer(A), ancestor(A,C), ancestor(A,E), ref(E,F), sizeOf(C), ancestor(C,B), 
	ancestor(G,F), ancestor(G,H), alloc(H), ancestor(H,I), not(sizeOf(I)).
"""))

# %% [markdown]
# By directly tagging `A` and `G`, maybe our system will only have to find:
#
#   - the small sub graphs rooted at `A` and `G` respectively
#   - the reference edge linking them

# %% [markdown]
# In the section below we load in the dataset as in the "Joern-ey into Progol" notebook.

# %%
ilp_data = pd.read_csv("../data/ilp_dataset.csv.gz")
ilp_data = ilp_data.drop("Unnamed: 0", axis=1)
ilp_data.head()
# Out:
#    testcase_ID                                           filename  \
# 0        62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 1        62821  000/062/821/CWE121_Stack_Based_Buffer_Overflow...
# 2        62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 3        62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 4        62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
#
#                                                 code     flaw  flaw_loc  \
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        35
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
#
#      bug  code_length
# 0  False         1722
# 1  False         1808
# 2  False         1674
# 3  False         2396
# 4  False         2414

# %%
prolog = pd.read_csv("../data/ilp_prolog_data.csv.gz")
prolog = prolog.drop("Unnamed: 0", axis=1)
prolog.head()
# Out:
#    testcase_ID     flaw   bug  code_length  \
# 0      -232086  CWE-122  True         1625
# 1      -232012  CWE-122  True         1619
# 2       -62917  CWE-121  True         1622
# 3       -62916  CWE-121  True         1649
# 4       -62915  CWE-121  True         1638
#
#                                                 tree  \
# 0  % START: Generated Prolog\n% NODE PROPERTIES \...
# 1  % START: Generated Prolog\n% NODE PROPERTIES \...
# 2  % START: Generated Prolog\n% NODE PROPERTIES \...
# 3  % START: Generated Prolog\n% NODE PROPERTIES \...
# 4  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                           source_map
# 0  % CODE\nsource_code(bad_232086_id_1_f_l_c_, "p...
# 1  % CODE\nsource_code(bad_232012_id_0_f_l_c_, "p...
# 2  % CODE\nsource_code(bad_62917_id_0_f_l_c_, "p1...
# 3  % CODE\nsource_code(bad_62916_id_1_f_l_c_, "p1...
# 4  % CODE\nsource_code(bad_62915_id_0_f_l_c_, "p1...

# %%
juliet = pd.read_csv("../data/buffer_overflow_data.csv.gz")
juliet.drop("Unnamed: 0", axis=1)

prolog['source_code'] = ''
prolog['flaw_loc'] = 0
prolog['bad_code'] = ''

for i in range(len(prolog)):
    label = prolog.iloc[i].testcase_ID == juliet.testcase_ID
    prolog['source_code'].iloc[i] = juliet.loc[label].iloc[0].code
    prolog['flaw_loc'].iloc[i] = juliet.loc[label].iloc[0].flaw_loc
    
for i in range(len(prolog)):
    loc =  prolog.iloc[i].flaw_loc
    testcase_ID = prolog.iloc[i].testcase_ID
    if testcase_ID < 0:
        prolog['bad_code'].iloc[i] = prolog.iloc[i].source_code.split('\n')[loc-1].strip()[0:-1]
    else:
        prolog['bad_code'].iloc[i] = prolog.loc[prolog.testcase_ID == -testcase_ID].iloc[0].bad_code
        
good_examples = prolog[prolog['bug'] == False]
bad_examples = prolog[prolog['bug'] == True]
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
def extract_node_ids(tree):
    nodes = set()
    
    in_ast_section = False
    
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% AST':
            in_ast_section = True
        
        if line == '% CFG':
            in_ast_section = False
            
        if line == '% REF':
            in_ast_section = False
        
        if in_ast_section and not line.startswith("%"):
            parent, child = line[4:-2].split(", ")
            nodes.add(parent)
            nodes.add(child)
            
    return nodes

# %%
# good nodes_g
nodes_g = set()

for i in range(len(good_examples)):
    good_nodes = extract_node_ids(good_examples.iloc[i].tree)
    nodes_g = set.union(nodes_g,good_nodes)

    
# bad nodes_b
nodes_b = set()

for i in range(len(bad_examples)):
    bad_nodes = extract_node_ids(bad_examples.iloc[i].tree)
    nodes_b = set.union(nodes_b,bad_nodes)

nodes = set.union(nodes_g,nodes_b)

# %%
def find_bug_id(good_examples, i = 0):
    tree = good_examples.source_map.iloc[i]
    parents = []
    children = []
    in_code_section = False
    temp = 0
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% CODE':
            in_code_section = True
        
        if in_code_section and not line.startswith("%"):
            try:
                #import pdb; pdb.set_trace()
                parent, child = line[12:-3].split(', "')
                parents.append(parent)
                children.append(child)
            except:
                temp +=1
    zipbObj = zip(children, parents)
    bug_node = dict(zipbObj)
    
    loc = good_examples.iloc[i].flaw_loc
    source_code = good_examples.iloc[i].bad_code

    return bug_node[source_code]

# %%
bad_node = []
good_node = []
for i in range(20):
    bad_node.append(find_bug_id(bad_examples,i))
    good_node.append(find_bug_id(good_examples,i))

# %%
node_and_tree = []
for node in nodes:
    start, end = node.split('_id')
    node_and_tree.append('(' +start+ ', ' +node+ ')')

node_and_tree[0:5]
# Out:
# ['(good_62900, good_62900_id_59_f_l_c_)',
#  '(good_62852, good_62852_id_45_f_l_c_)',
#  '(bad_62917, bad_62917_id_119_f_memmove_18_c_l_31_c_16_)',
#  '(bad_62913, bad_62913_id_22_f_l_c_)',
#  '(good_232086, good_232086_id_160_f_memmove_01_c_l_28_c_22_)']

# %%
node_tree_types = [
    'node_in_tree'+ node_tree +'.' for node_tree in node_and_tree
]

# %%
node_types = [
    'node('+ node_id +').' for node_id in nodes
]

# %%
def extract_tree_ids(tree):
    line = tree.split('\n')[2]
    line = line.strip()
    line = line.split('(')[1]
    tree_id = line.split('_id')[0]

    return tree_id

# %%
tree_ids = []
for tree in prolog.tree:
    tree_ids.append(extract_tree_ids(tree))

# %%
trees = [
    'tree('+ tree_label +').' for tree_label in tree_ids
]

# %%
positive_examples
# Out:
# ['bug(bad_232086_id_168_f_memmove_01_c_l_25_c_4_,bad_232086_id_145_f_memmove_01_c_l_30_c_8_).',
#  'bug(bad_232012_id_168_f_memcpy_01_c_l_25_c_4_,bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).',
#  'bug(bad_62917_id_132_f_memmove_18_c_l_27_c_4_,bad_62917_id_121_f_memmove_18_c_l_31_c_8_).',
#  'bug(bad_62916_id_144_f_memmove_17_c_l_28_c_8_,bad_62916_id_133_f_memmove_17_c_l_33_c_8_).',
#  'bug(bad_62915_id_133_f_memmove_16_c_l_27_c_8_,bad_62915_id_121_f_memmove_16_c_l_33_c_8_).',
#  'bug(bad_62913_id_139_f_memmove_14_c_l_27_c_8_,bad_62913_id_127_f_memmove_14_c_l_32_c_8_).',
#  'bug(bad_62909_id_132_f_memmove_10_c_l_27_c_8_,bad_62909_id_121_f_memmove_10_c_l_32_c_8_).',
#  'bug(bad_62902_id_139_f_memmove_03_c_l_27_c_8_,bad_62902_id_127_f_memmove_03_c_l_32_c_8_).',
#  'bug(bad_62901_id_132_f_memmove_02_c_l_27_c_8_,bad_62901_id_121_f_memmove_02_c_l_32_c_8_).',
#  'bug(bad_62900_id_132_f_memmove_01_c_l_25_c_4_,bad_62900_id_121_f_memmove_01_c_l_29_c_8_).',
#  'bug(bad_62869_id_132_f_memcpy_18_c_l_27_c_4_,bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).',
#  'bug(bad_62868_id_144_f_memcpy_17_c_l_28_c_8_,bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).',
#  'bug(bad_62867_id_133_f_memcpy_16_c_l_27_c_8_,bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).',
#  'bug(bad_62865_id_139_f_memcpy_14_c_l_27_c_8_,bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).',
#  'bug(bad_62861_id_132_f_memcpy_10_c_l_27_c_8_,bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).',
#  'bug(bad_62854_id_139_f_memcpy_03_c_l_27_c_8_,bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).',
#  'bug(bad_62853_id_132_f_memcpy_02_c_l_27_c_8_,bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).',
#  'bug(bad_62852_id_132_f_memcpy_01_c_l_25_c_4_,bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).',
#  'bug(bad_62821_id_135_f_loop_18_c_l_27_c_4_,bad_62821_id_110_f_loop_18_c_l_34_c_12_).',
#  'bug(bad_62804_id_135_f_loop_01_c_l_25_c_4_,bad_62804_id_110_f_loop_01_c_l_32_c_12_).']

# %%
def make_progol_script(header, positive_examples, negative_examples, testcases=None):
    script_template = """
{header}

%% Trees
{trees}

%% Types
{types}

%% background knowledge
{bg_knowledge}

%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """
    script = script_template.format(
        header = header,
        trees =  '\n'.join(trees),
        types = '\n'.join(node_tree_types + node_types),
        bg_knowledge = '\n'.join(prolog['tree']),
        positive_examples='\n'.join(positive_examples),
        negative_examples='\n'.join(negative_examples),
    )
    
    # keep all testcases unless a testcases set is given in fn call
    if testcases:
        # remove all lines not related to this testcase
        script = '\n'.join([
            line for line in script.split("\n")  if any(
                str(testcase) in line for testcase in testcases
            ) or not ("good_" in line or "bad_" in line)
        ])
    
    return script

# %% [markdown]
# Here we try to locate the buggy nodes. For each test case this will be:
#   1. Location where the memory is _allocated_.
#   2. Location where the memory is _written to_.
#
# We already have code above to find the latter. Can we find the first as well?

# %%
bad_write_nodes = bad_node
good_write_nodes = good_node

# %%
# this code is horrible sorry. if you need to figure out what it does speak to Dan.

alloc_source_maps = [
    line
    for source_map in prolog['source_map']
    for line in source_map.split("\n")
    if 'data =' in line.lower() and 'alloc' in line.lower()
]
bad_alloc_nodes = [
    source_map.strip("source_code(").split(",")[0]
    for source_map in alloc_source_maps
    if 'bad' in source_map
]

good_alloc_nodes = [
    source_map.strip("source_code(").split(",")[0]
    for source_map in alloc_source_maps
    if 'good' in source_map
]

positive_examples = []
for write_node in bad_write_nodes:
    # find the alloc node which has a line number before the write
    write_node_id = write_node.strip("source_code(").split(",")[0] + "_"
    write_line = int(write_node_id.split("_")[-4])
    
    testcase_id = '_'.join(write_node_id.split("_")[0:2])
    
    potential_alloc_nodes = [node for node in bad_alloc_nodes if testcase_id in node]
    for alloc_node in potential_alloc_nodes:
        alloc_node_id = alloc_node.strip("source_code(").split(",")[0] + "_"
        alloc_line = int(alloc_node_id.split("_")[-4])
        
        if alloc_line <= write_line:
            positive_examples.append(
                "bug({},{}).".format(alloc_node_id, write_node_id)
            )
            
negative_examples = []
for write_node in good_write_nodes:
    # find the alloc node which has a line number before the write
    write_node_id = write_node.strip("source_code(").split(",")[0] + "_"
    write_line = int(write_node_id.split("_")[-4])
    
    testcase_id = '_'.join(write_node_id.split("_")[0:2])
    
    potential_alloc_nodes = [node for node in good_alloc_nodes if testcase_id in node]
    for alloc_node in potential_alloc_nodes:
        alloc_node_id = alloc_node.strip("source_code(").split(",")[0] + "_"
        alloc_line = int(alloc_node_id.split("_")[-4])
        
        if alloc_line <= write_line:
            negative_examples.append(
                ":- bug({},{}).".format(alloc_node_id, write_node_id)
            )

# %% [markdown]
# Next we experiment with settings and different rule structures to see if it can learn a rule:

# %%
header = """
% Settings
:-randomseed?
:- set(c,5000)?
:- set(i,5000)?
:- set(h,5000)?
:- set(r,5000)?
:- set(cover)?
:- set(inflate,2000)?
%:- set(posonly)?
:- set(memoing)?
:- set(nodes,20000)?
%:- set(reductive)?
:- set(splitting)?

%:- generalise(bug/20)?

% Mode declarations
:- modeh(*, bug(+node,+node))?

%:- modeb(*, same_tree(+node,+node))?
%:- modeb(*, same_tree(+node,-node))?
%:- modeb(*, same_tree(-node,+node))?
%:- modeb(*, same_tree(-node,-node))?

%:- modeb(5, runs_before(+node,-node))?
:- modeb(10, ancestor(+node, -node))?
%:- modeb(5, ast(+node,-node))?
:- modeb(10, cfg(+node, -node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
%:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(*, alloc_doesnt_check_sizeOf(+node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

writeToPointer(A) :- ast(A,B), assignment(A), compMemberAccess(B). 

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).

contains_sizeOf_call(A) :- ancestor(A, B), sizeof(B).
alloc_doesnt_check_sizeOf(A) :- alloc(A), not(contains_sizeOf_call(A)).

same_tree(A,B) :- node_in_tree(T,A), node_in_tree(T,B).
"""

script = make_progol_script(
    header,
    positive_examples,
    negative_examples,
)

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [The random number generator seed has been reset using the time of day]
# [:- randomseed? - Time taken 0.00s]
# [:- set(c,5000)? - Time taken 0.00s]
# [:- set(i,5000)? - Time taken 0.00s]
# [:- set(h,5000)? - Time taken 0.00s]
# [:- set(r,5000)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,2000)? - Time taken 0.00s]
# [The memoing flag has been turned ON]
# [:- set(memoing)? - Time taken 0.00s]
# [:- set(nodes,20000)? - Time taken 0.00s]
# [The splitting flag has been turned ON]
# [:- set(splitting)? - Time taken 0.00s]
# [:- modeh(100,bug(+node,+node))? - Time taken 0.00s]
# [:- modeb(10,ancestor(+node,-node))? - Time taken 0.00s]
# [:- modeb(10,cfg(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc_doesnt_check_sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,pointer(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOfInt(+node))? - Time taken 0.00s]
# [:- modeb(100,array10(+node))? - Time taken 0.00s]
# [:- modeb(100,voidPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/2]
# [Generalising bug(bad_232086_id_168_f_memmove_01_c_l_25_c_4_,bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_168_f_memmove_01_c_l_25_c_4_,bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,O), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), pointer(I), ancestor(L,C), ancestor(K,F), cfg(L,A), cfg(N,P), cfg(M,Q), cfg(K,B), ref(R,O), ref(S,O), ref(T,O), ref(U,O), pointer(O), cfg(Q,V), cfg(P,W), cfg(P,X), cfg(R,Y), cfg(S,Z), cfg(T,C), cfg(U,A0), pointer(R), pointer(S), pointer(T), pointer(U), ancestor(V,J), ancestor(V,M), cfg(W,B0), cfg(X,C0), cfg(A0,D0), cfg(Z,H), cfg(Y,E0), cfg(V,R), ref(W,F0), ref(Z,F0), sizeOfInt(W), sizeOfInt(Z), array10(W), array10(Z), cfg(C0,G0), cfg(B0,S), cfg(D0,T), assignment(B0), assignment(D0), sizeOfInt(F0), array10(F0), voidPointer(E0), ancestor(G0,X), cfg(G0,W).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,N),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	pointer(H), ancestor(K,C), ancestor(J,E), cfg(K,A),
# 	cfg(M,O), cfg(L,P), cfg(J,B), ref(Q,N), ref(R,N), ref(S,
# 	N), ref(T,N), pointer(N), cfg(P,U), cfg(O,V), cfg(O,W),
# 	cfg(Q,X), cfg(R,Y), cfg(S,C), cfg(T,Z), pointer(Q),
# 	pointer(R), pointer(S), pointer(T), ancestor(U,I), ancestor(U,
# 	L), cfg(V,A0), cfg(W,B0), cfg(Z,C0), cfg(Y,G), cfg(X,
# 	D0), cfg(U,Q), ref(V,E0), ref(Y,E0), sizeOfInt(V), sizeOfInt(Y),
# 	array10(V), array10(Y), cfg(B0,F0), cfg(A0,R), cfg(C0,
# 	S), assignment(A0), assignment(C0), sizeOfInt(E0), array10(E0),
# 	voidPointer(D0), ancestor(F0,W), cfg(F0,V).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_168_f_memcpy_01_c_l_25_c_4_,bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_168_f_memcpy_01_c_l_25_c_4_,bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,O), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), pointer(I), ancestor(L,C), ancestor(K,F), cfg(L,A), cfg(M,P), cfg(N,Q), cfg(K,B), ref(R,O), ref(S,O), ref(T,O), ref(U,O), pointer(O), cfg(P,V), cfg(Q,W), cfg(Q,X), cfg(R,Y), cfg(S,Z), cfg(T,C), cfg(U,A0), pointer(R), pointer(S), pointer(T), pointer(U), ancestor(V,J), ancestor(V,M), cfg(Z,H), cfg(W,B0), cfg(X,C0), cfg(Y,D0), cfg(V,R), cfg(A0,E0), ref(Z,F0), ref(W,F0), sizeOfInt(Z), sizeOfInt(W), array10(Z), array10(W), cfg(E0,T), cfg(B0,S), cfg(C0,G0), assignment(E0), assignment(B0), sizeOfInt(F0), array10(F0), voidPointer(D0), ancestor(G0,X), cfg(G0,W).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,N),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	pointer(H), ancestor(K,C), ancestor(J,E), cfg(K,A),
# 	cfg(L,O), cfg(M,P), cfg(J,B), ref(Q,N), ref(R,N), ref(S,
# 	N), ref(T,N), pointer(N), cfg(O,U), cfg(P,V), cfg(P,W),
# 	cfg(Q,X), cfg(R,Y), cfg(S,C), cfg(T,Z), pointer(Q),
# 	pointer(R), pointer(S), pointer(T), ancestor(U,I), ancestor(U,
# 	L), cfg(Y,G), cfg(V,A0), cfg(W,B0), cfg(X,C0), cfg(U,
# 	Q), cfg(Z,D0), ref(Y,E0), ref(V,E0), sizeOfInt(Y), sizeOfInt(V),
# 	array10(Y), array10(V), cfg(D0,S), cfg(A0,R), cfg(B0,
# 	F0), assignment(D0), assignment(A0), sizeOfInt(E0), array10(E0),
# 	voidPointer(C0), ancestor(F0,W), cfg(F0,V).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_132_f_memmove_18_c_l_27_c_4_,bad_62917_id_121_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_132_f_memmove_18_c_l_27_c_4_,bad_62917_id_121_f_memmove_18_c_l_31_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(K,F), ancestor(L,C), cfg(K,B), cfg(N,Q), cfg(L,A), cfg(M,R), ref(Q,O), ref(S,P), ref(T,O), ref(U,O), assignment(N), pointer(O), sizeOfInt(P), array10(P), cfg(Q,S), cfg(R,V), cfg(S,H), cfg(T,C), cfg(U,W), pointer(Q), pointer(T), pointer(U), sizeOfInt(S), array10(S), ancestor(V,J), ancestor(V,M), cfg(V,X), cfg(W,Y), cfg(Y,Z), assignment(Y), voidPointer(X), cfg(Z,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(J,E), ancestor(K,
# 	C), cfg(J,B), cfg(M,P), cfg(K,A), cfg(L,Q), ref(P,N),
# 	ref(R,O), ref(S,N), ref(T,N), assignment(M), pointer(N),
# 	sizeOfInt(O), array10(O), cfg(P,R), cfg(Q,U), cfg(R,
# 	G), cfg(S,C), cfg(T,V), pointer(P), pointer(S), pointer(T),
# 	sizeOfInt(R), array10(R), ancestor(U,I), ancestor(U,
# 	L), cfg(U,W), cfg(V,X), cfg(X,Y), assignment(X), voidPointer(W),
# 	cfg(Y,S).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62916_id_144_f_memmove_17_c_l_28_c_8_,bad_62916_id_133_f_memmove_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62916_id_144_f_memmove_17_c_l_28_c_8_,bad_62916_id_133_f_memmove_17_c_l_33_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), ancestor(K,F), ancestor(L,C), cfg(M,Q), cfg(K,B), cfg(L,A), cfg(N,R), ref(R,P), ref(S,P), ref(T,O), ref(U,O), ref(V,O), pointer(O), cfg(R,W), cfg(Q,X), cfg(S,Y), cfg(T,Z), cfg(U,C), cfg(V,A0), pointer(T), pointer(U), pointer(V), ancestor(X,J), ancestor(X,M), cfg(X,B0), cfg(Z,H), cfg(A0,C0), cfg(W,D0), cfg(Y,E0), ref(Z,F0), sizeOfInt(Z), array10(Z), cfg(E0,R), cfg(C0,S), cfg(D0,U), cfg(D0,G0), ref(G0,F0), assignment(E0), assignment(C0), sizeOfInt(F0), array10(F0), voidPointer(B0), cfg(G0,H0), sizeOfInt(G0), array10(G0), cfg(H0,T), assignment(H0).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	ancestor(J,E), ancestor(K,C), cfg(L,P), cfg(J,B), cfg(K,
# 	A), cfg(M,Q), ref(Q,O), ref(R,O), ref(S,N), ref(T,N),
# 	ref(U,N), pointer(N), cfg(Q,V), cfg(P,W), cfg(R,X),
# 	cfg(S,Y), cfg(T,C), cfg(U,Z), pointer(S), pointer(T),
# 	pointer(U), ancestor(W,I), ancestor(W,L), cfg(W,A0),
# 	cfg(Y,G), cfg(Z,B0), cfg(V,C0), cfg(X,D0), ref(Y,E0),
# 	sizeOfInt(Y), array10(Y), cfg(D0,Q), cfg(B0,R), cfg(C0,
# 	T), cfg(C0,F0), ref(F0,E0), assignment(D0), assignment(B0),
# 	sizeOfInt(E0), array10(E0), voidPointer(A0), cfg(F0,
# 	G0), sizeOfInt(F0), array10(F0), cfg(G0,S), assignment(G0).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62915_id_133_f_memmove_16_c_l_27_c_8_,bad_62915_id_121_f_memmove_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62915_id_133_f_memmove_16_c_l_27_c_8_,bad_62915_id_121_f_memmove_16_c_l_33_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(J,O), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), ancestor(K,C), ancestor(L,F), cfg(K,A), cfg(L,B), cfg(N,P), cfg(M,Q), ref(M,R), ref(S,O), ref(T,O), ref(U,O), pointer(O), sizeOfInt(M), array10(M), cfg(Q,S), cfg(P,V), cfg(S,W), cfg(T,C), cfg(U,X), ref(W,R), assignment(Q), pointer(S), pointer(T), pointer(U), sizeOfInt(R), array10(R), ancestor(V,J), ancestor(V,N), cfg(V,Y), cfg(X,Z), cfg(W,H), sizeOfInt(W), array10(W), cfg(Z,A0), assignment(Z), voidPointer(Y), cfg(A0,M), cfg(A0,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(I,N), sizeOf(F),
# 	alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	ancestor(J,C), ancestor(K,E), cfg(J,A), cfg(K,B), cfg(M,
# 	O), cfg(L,P), ref(L,Q), ref(R,N), ref(S,N), ref(T,N),
# 	pointer(N), sizeOfInt(L), array10(L), cfg(P,R), cfg(O,
# 	U), cfg(R,V), cfg(S,C), cfg(T,W), ref(V,Q), assignment(P),
# 	pointer(R), pointer(S), pointer(T), sizeOfInt(Q), array10(Q),
# 	ancestor(U,I), ancestor(U,M), cfg(U,X), cfg(W,Y), cfg(V,
# 	G), sizeOfInt(V), array10(V), cfg(Y,Z), assignment(Y),
# 	voidPointer(X), cfg(Z,L), cfg(Z,S).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62913_id_139_f_memmove_14_c_l_27_c_8_,bad_62913_id_127_f_memmove_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62913_id_139_f_memmove_14_c_l_27_c_8_,bad_62913_id_127_f_memmove_14_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(L,F), ancestor(K,C), cfg(L,B), cfg(N,Q), cfg(K,A), cfg(M,R), ref(R,P), ref(S,P), ref(T,P), ref(U,O), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(Q,V), cfg(R,U), cfg(S,C), cfg(T,W), cfg(U,H), pointer(R), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,N), cfg(V,X), cfg(W,Y), cfg(Y,Z), assignment(Y), voidPointer(X), cfg(Z,A0), cfg(A0,B0), cfg(B0,I), cfg(B0,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(K,E), ancestor(J,
# 	C), cfg(K,B), cfg(M,P), cfg(J,A), cfg(L,Q), ref(Q,O),
# 	ref(R,O), ref(S,O), ref(T,N), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(P,U), cfg(Q,T), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(Q), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	M), cfg(U,W), cfg(V,X), cfg(X,Y), assignment(X), voidPointer(W),
# 	cfg(Y,Z), cfg(Z,A0), cfg(A0,H), cfg(A0,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62909_id_132_f_memmove_10_c_l_27_c_8_,bad_62909_id_121_f_memmove_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62909_id_132_f_memmove_10_c_l_27_c_8_,bad_62909_id_121_f_memmove_10_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(K,C), ancestor(L,F), cfg(N,Q), cfg(K,A), cfg(M,R), cfg(L,B), ref(R,P), ref(S,O), ref(T,P), ref(U,P), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(Q,V), cfg(R,S), cfg(S,H), cfg(T,C), cfg(U,W), pointer(R), pointer(T), pointer(U), sizeOfInt(S), array10(S), ancestor(V,J), ancestor(V,N), cfg(W,X), cfg(V,Y), cfg(X,Z), assignment(X), voidPointer(Y), cfg(Z,I), cfg(Z,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(J,C), ancestor(K,
# 	E), cfg(M,P), cfg(J,A), cfg(L,Q), cfg(K,B), ref(Q,O),
# 	ref(R,N), ref(S,O), ref(T,O), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(P,U), cfg(Q,R), cfg(R,
# 	G), cfg(S,C), cfg(T,V), pointer(Q), pointer(S), pointer(T),
# 	sizeOfInt(R), array10(R), ancestor(U,I), ancestor(U,
# 	M), cfg(V,W), cfg(U,X), cfg(W,Y), assignment(W), voidPointer(X),
# 	cfg(Y,H), cfg(Y,S).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62902_id_139_f_memmove_03_c_l_27_c_8_,bad_62902_id_127_f_memmove_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62902_id_139_f_memmove_03_c_l_27_c_8_,bad_62902_id_127_f_memmove_03_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(K,F), ancestor(L,C), cfg(K,B), cfg(N,Q), cfg(M,R), cfg(L,A), ref(Q,O), ref(S,O), ref(T,O), ref(U,P), assignment(N), pointer(O), sizeOfInt(P), array10(P), cfg(R,V), cfg(Q,U), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,M), cfg(V,X), cfg(W,Y), cfg(Y,Z), assignment(Y), voidPointer(X), cfg(Z,A0), cfg(A0,B0), cfg(B0,I), cfg(B0,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(J,E), ancestor(K,
# 	C), cfg(J,B), cfg(M,P), cfg(L,Q), cfg(K,A), ref(P,N),
# 	ref(R,N), ref(S,N), ref(T,O), assignment(M), pointer(N),
# 	sizeOfInt(O), array10(O), cfg(Q,U), cfg(P,T), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	L), cfg(U,W), cfg(V,X), cfg(X,Y), assignment(X), voidPointer(W),
# 	cfg(Y,Z), cfg(Z,A0), cfg(A0,H), cfg(A0,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_132_f_memmove_02_c_l_27_c_8_,bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_132_f_memmove_02_c_l_27_c_8_,bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(L,F), ancestor(K,C), cfg(L,B), cfg(N,Q), cfg(M,R), cfg(K,A), ref(R,P), ref(S,P), ref(T,P), ref(U,O), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(R,U), cfg(Q,V), cfg(S,C), cfg(T,W), cfg(U,H), pointer(R), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,N), cfg(W,X), cfg(V,Y), cfg(X,Z), assignment(X), voidPointer(Y), cfg(Z,I), cfg(Z,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(K,E), ancestor(J,
# 	C), cfg(K,B), cfg(M,P), cfg(L,Q), cfg(J,A), ref(Q,O),
# 	ref(R,O), ref(S,O), ref(T,N), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(Q,T), cfg(P,U), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(Q), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	M), cfg(V,W), cfg(U,X), cfg(W,Y), assignment(W), voidPointer(X),
# 	cfg(Y,H), cfg(Y,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_132_f_memmove_01_c_l_25_c_4_,bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_132_f_memmove_01_c_l_25_c_4_,bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(K,C), ancestor(L,F), cfg(M,Q), cfg(K,A), cfg(L,B), cfg(N,R), ref(Q,P), ref(S,P), ref(T,P), ref(U,O), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(R,V), cfg(Q,U), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,N), cfg(W,X), cfg(V,Y), cfg(X,S), assignment(X), voidPointer(Y).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(J,C), ancestor(K,
# 	E), cfg(L,P), cfg(J,A), cfg(K,B), cfg(M,Q), ref(P,O),
# 	ref(R,O), ref(S,O), ref(T,N), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(Q,U), cfg(P,T), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	M), cfg(V,W), cfg(U,X), cfg(W,R), assignment(W), voidPointer(X).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_132_f_memcpy_18_c_l_27_c_4_,bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_132_f_memcpy_18_c_l_27_c_4_,bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(L,C), ancestor(K,F), cfg(N,Q), cfg(L,A), cfg(K,B), cfg(M,R), ref(Q,O), ref(S,O), ref(T,O), ref(U,P), assignment(N), pointer(O), sizeOfInt(P), array10(P), cfg(Q,U), cfg(R,V), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,M), cfg(V,X), cfg(W,Y), cfg(Y,Z), assignment(Y), voidPointer(X), cfg(Z,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(K,C), ancestor(J,
# 	E), cfg(M,P), cfg(K,A), cfg(J,B), cfg(L,Q), ref(P,N),
# 	ref(R,N), ref(S,N), ref(T,O), assignment(M), pointer(N),
# 	sizeOfInt(O), array10(O), cfg(P,T), cfg(Q,U), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	L), cfg(U,W), cfg(V,X), cfg(X,Y), assignment(X), voidPointer(W),
# 	cfg(Y,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62868_id_144_f_memcpy_17_c_l_28_c_8_,bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62868_id_144_f_memcpy_17_c_l_28_c_8_,bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), ancestor(L,C), ancestor(K,F), cfg(N,Q), cfg(L,A), cfg(M,R), cfg(K,B), ref(Q,P), ref(S,P), ref(T,O), ref(U,O), ref(V,O), pointer(O), cfg(R,W), cfg(Q,X), cfg(S,Y), cfg(T,Z), cfg(U,C), cfg(V,A0), pointer(T), pointer(U), pointer(V), ancestor(W,J), ancestor(W,M), cfg(W,B0), cfg(Z,H), cfg(X,C0), cfg(Y,D0), cfg(A0,E0), ref(Z,F0), sizeOfInt(Z), array10(Z), cfg(D0,Q), cfg(C0,U), cfg(C0,G0), cfg(E0,S), ref(G0,F0), assignment(D0), assignment(E0), sizeOfInt(F0), array10(F0), voidPointer(B0), cfg(G0,H0), sizeOfInt(G0), array10(G0), cfg(H0,T), assignment(H0).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	ancestor(K,C), ancestor(J,E), cfg(M,P), cfg(K,A), cfg(L,
# 	Q), cfg(J,B), ref(P,O), ref(R,O), ref(S,N), ref(T,N),
# 	ref(U,N), pointer(N), cfg(Q,V), cfg(P,W), cfg(R,X),
# 	cfg(S,Y), cfg(T,C), cfg(U,Z), pointer(S), pointer(T),
# 	pointer(U), ancestor(V,I), ancestor(V,L), cfg(V,A0),
# 	cfg(Y,G), cfg(W,B0), cfg(X,C0), cfg(Z,D0), ref(Y,E0),
# 	sizeOfInt(Y), array10(Y), cfg(C0,P), cfg(B0,T), cfg(B0,
# 	F0), cfg(D0,R), ref(F0,E0), assignment(C0), assignment(D0),
# 	sizeOfInt(E0), array10(E0), voidPointer(A0), cfg(F0,
# 	G0), sizeOfInt(F0), array10(F0), cfg(G0,S), assignment(G0).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62867_id_133_f_memcpy_16_c_l_27_c_8_,bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62867_id_133_f_memcpy_16_c_l_27_c_8_,bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), ancestor(K,F), ancestor(L,C), cfg(K,B), cfg(M,P), cfg(N,Q), cfg(L,A), ref(N,R), ref(S,O), ref(T,O), ref(U,O), pointer(O), sizeOfInt(N), array10(N), cfg(Q,S), cfg(P,V), cfg(S,W), cfg(T,C), cfg(U,X), ref(W,R), assignment(Q), pointer(S), pointer(T), pointer(U), sizeOfInt(R), array10(R), ancestor(V,J), ancestor(V,M), cfg(V,Y), cfg(X,Z), cfg(W,H), sizeOfInt(W), array10(W), cfg(Z,A0), assignment(Z), voidPointer(Y), cfg(A0,N), cfg(A0,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), sizeOf(F),
# 	alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	ancestor(J,E), ancestor(K,C), cfg(J,B), cfg(L,O), cfg(M,
# 	P), cfg(K,A), ref(M,Q), ref(R,N), ref(S,N), ref(T,N),
# 	pointer(N), sizeOfInt(M), array10(M), cfg(P,R), cfg(O,
# 	U), cfg(R,V), cfg(S,C), cfg(T,W), ref(V,Q), assignment(P),
# 	pointer(R), pointer(S), pointer(T), sizeOfInt(Q), array10(Q),
# 	ancestor(U,I), ancestor(U,L), cfg(U,X), cfg(W,Y), cfg(V,
# 	G), sizeOfInt(V), array10(V), cfg(Y,Z), assignment(Y),
# 	voidPointer(X), cfg(Z,M), cfg(Z,S).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62865_id_139_f_memcpy_14_c_l_27_c_8_,bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62865_id_139_f_memcpy_14_c_l_27_c_8_,bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(L,F), ancestor(K,C), cfg(L,B), cfg(M,Q), cfg(K,A), cfg(N,R), ref(Q,P), ref(S,P), ref(T,P), ref(U,O), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(Q,U), cfg(R,V), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,N), cfg(W,X), cfg(V,Y), cfg(X,Z), assignment(X), voidPointer(Y), cfg(Z,A0), cfg(A0,B0), cfg(B0,I), cfg(B0,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(K,E), ancestor(J,
# 	C), cfg(K,B), cfg(L,P), cfg(J,A), cfg(M,Q), ref(P,O),
# 	ref(R,O), ref(S,O), ref(T,N), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(P,T), cfg(Q,U), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	M), cfg(V,W), cfg(U,X), cfg(W,Y), assignment(W), voidPointer(X),
# 	cfg(Y,Z), cfg(Z,A0), cfg(A0,H), cfg(A0,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62861_id_132_f_memcpy_10_c_l_27_c_8_,bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62861_id_132_f_memcpy_10_c_l_27_c_8_,bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(K,C), ancestor(L,F), cfg(N,Q), cfg(K,A), cfg(L,B), cfg(M,R), ref(R,P), ref(S,O), ref(T,P), ref(U,P), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(R,S), cfg(Q,V), cfg(S,H), cfg(T,C), cfg(U,W), pointer(R), pointer(T), pointer(U), sizeOfInt(S), array10(S), ancestor(V,J), ancestor(V,N), cfg(V,X), cfg(W,Y), cfg(Y,Z), assignment(Y), voidPointer(X), cfg(Z,I), cfg(Z,T).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(J,C), ancestor(K,
# 	E), cfg(M,P), cfg(J,A), cfg(K,B), cfg(L,Q), ref(Q,O),
# 	ref(R,N), ref(S,O), ref(T,O), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(Q,R), cfg(P,U), cfg(R,
# 	G), cfg(S,C), cfg(T,V), pointer(Q), pointer(S), pointer(T),
# 	sizeOfInt(R), array10(R), ancestor(U,I), ancestor(U,
# 	M), cfg(U,W), cfg(V,X), cfg(X,Y), assignment(X), voidPointer(W),
# 	cfg(Y,H), cfg(Y,S).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_139_f_memcpy_03_c_l_27_c_8_,bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_139_f_memcpy_03_c_l_27_c_8_,bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(L,C), ancestor(K,F), cfg(L,A), cfg(N,Q), cfg(M,R), cfg(K,B), ref(Q,O), ref(S,O), ref(T,O), ref(U,P), assignment(N), pointer(O), sizeOfInt(P), array10(P), cfg(Q,U), cfg(R,V), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,M), cfg(W,X), cfg(V,Y), cfg(X,Z), assignment(X), voidPointer(Y), cfg(Z,A0), cfg(A0,B0), cfg(B0,I), cfg(B0,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(K,C), ancestor(J,
# 	E), cfg(K,A), cfg(M,P), cfg(L,Q), cfg(J,B), ref(P,N),
# 	ref(R,N), ref(S,N), ref(T,O), assignment(M), pointer(N),
# 	sizeOfInt(O), array10(O), cfg(P,T), cfg(Q,U), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	L), cfg(V,W), cfg(U,X), cfg(W,Y), assignment(W), voidPointer(X),
# 	cfg(Y,Z), cfg(Z,A0), cfg(A0,H), cfg(A0,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_132_f_memcpy_02_c_l_27_c_8_,bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_132_f_memcpy_02_c_l_27_c_8_,bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(F,G), cfg(G,K), cfg(H,F), cfg(C,D), cfg(D,L), cfg(J,M), cfg(I,N), ref(J,O), ref(I,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(K,F), ancestor(L,C), cfg(K,B), cfg(N,Q), cfg(M,R), cfg(L,A), ref(Q,O), ref(S,O), ref(T,O), ref(U,P), assignment(N), pointer(O), sizeOfInt(P), array10(P), cfg(Q,U), cfg(R,V), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,M), cfg(W,X), cfg(V,Y), cfg(X,Z), assignment(X), voidPointer(Y), cfg(Z,I), cfg(Z,S).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
# 	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(J,E), ancestor(K,
# 	C), cfg(J,B), cfg(M,P), cfg(L,Q), cfg(K,A), ref(P,N),
# 	ref(R,N), ref(S,N), ref(T,O), assignment(M), pointer(N),
# 	sizeOfInt(O), array10(O), cfg(P,T), cfg(Q,U), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	L), cfg(V,W), cfg(U,X), cfg(W,Y), assignment(W), voidPointer(X),
# 	cfg(Y,H), cfg(Y,R).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_132_f_memcpy_01_c_l_25_c_4_,bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_132_f_memcpy_01_c_l_25_c_4_,bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J), assignment(A), writeToPointer(B), cfg(C,D), cfg(D,K), cfg(F,G), cfg(G,L), cfg(H,F), cfg(I,M), cfg(J,N), ref(I,O), ref(J,P), sizeOf(G), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(J), sizeOfInt(I), array10(I), ancestor(L,F), ancestor(K,C), cfg(L,B), cfg(M,Q), cfg(K,A), cfg(N,R), ref(Q,P), ref(S,P), ref(T,P), ref(U,O), assignment(M), pointer(P), sizeOfInt(O), array10(O), cfg(Q,U), cfg(R,V), cfg(S,C), cfg(T,W), cfg(U,H), pointer(Q), pointer(S), pointer(T), sizeOfInt(U), array10(U), ancestor(V,J), ancestor(V,N), cfg(W,X), cfg(V,Y), cfg(X,S), assignment(X), voidPointer(Y).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
# 	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
# 	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
# 	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
# 	sizeOfInt(H), array10(H), ancestor(K,E), ancestor(J,
# 	C), cfg(K,B), cfg(L,P), cfg(J,A), cfg(M,Q), ref(P,O),
# 	ref(R,O), ref(S,O), ref(T,N), assignment(L), pointer(O),
# 	sizeOfInt(N), array10(N), cfg(P,T), cfg(Q,U), cfg(R,
# 	C), cfg(S,V), cfg(T,G), pointer(P), pointer(R), pointer(S),
# 	sizeOfInt(T), array10(T), ancestor(U,I), ancestor(U,
# 	M), cfg(V,W), cfg(U,X), cfg(W,R), assignment(W), voidPointer(X).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [10 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62821_id_135_f_loop_18_c_l_27_c_4_,bad_62821_id_110_f_loop_18_c_l_34_c_12_).]
# [Generalising <bug(bad_62821_id_135_f_loop_18_c_l_27_c_4_,bad_62821_id_110_f_loop_18_c_l_34_c_12_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), ancestor(B,I), cfg(A,J), cfg(B,K), assignment(A), assignment(B), writeToPointer(B), cfg(C,D), cfg(D,L), cfg(F,M), cfg(G,F), cfg(H,N), cfg(I,H), cfg(J,O), cfg(K,P), ref(F,Q), ref(G,R), ref(H,Q), ref(I,S), ref(J,R), ref(K,Q), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I), sizeOfInt(F), sizeOfInt(G), sizeOfInt(H), sizeOfInt(J), sizeOfInt(K), array10(G), array10(J), ancestor(L,C), cfg(N,G), cfg(M,B), cfg(O,T), cfg(L,A), cfg(P,U), ref(T,Q), ref(U,Q), ref(V,S), ref(W,S), ref(X,S), assignment(O), pointer(S), sizeOfInt(Q), sizeOfInt(R), array10(R), cfg(T,Y), cfg(U,Z), cfg(V,A0), cfg(W,C), cfg(X,B0), pointer(V), pointer(W), pointer(X), sizeOfInt(T), sizeOfInt(U), cfg(Z,C0), cfg(Y,D0), cfg(B0,E0), cfg(A0,F0), cfg(F0,G0), cfg(E0,H0), cfg(C0,I), cfg(C0,V), cfg(D0,U), assignment(E0), assignment(D0), ancestor(G0,V), ancestor(G0,A0), cfg(G0,I0), cfg(H0,W), voidPointer(I0).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J),
# 	assignment(A), assignment(B), writeToPointer(B), cfg(C,
# 	D), cfg(D,K), cfg(E,L), cfg(F,E), cfg(G,M), cfg(H,G),
# 	cfg(I,N), cfg(J,O), ref(E,P), ref(F,Q), ref(G,P), ref(H,
# 	R), ref(I,Q), ref(J,P), alloc(D), alloc_doesnt_check_sizeOf(D),
# 	pointer(H), sizeOfInt(E), sizeOfInt(F), sizeOfInt(G),
# 	sizeOfInt(I), sizeOfInt(J), array10(F), array10(I),
# 	ancestor(K,C), cfg(M,F), cfg(L,B), cfg(N,S), cfg(K,A),
# 	cfg(O,T), ref(S,P), ref(T,P), ref(U,R), ref(V,R), ref(W,
# 	R), assignment(N), pointer(R), sizeOfInt(P), sizeOfInt(Q),
# 	array10(Q), cfg(S,X), cfg(T,Y), cfg(U,Z), cfg(V,C),
# 	cfg(W,A0), pointer(U), pointer(V), pointer(W), sizeOfInt(S),
# 	sizeOfInt(T), cfg(Y,B0), cfg(X,C0), cfg(A0,D0), cfg(Z,
# 	E0), cfg(E0,F0), cfg(D0,G0), cfg(B0,H), cfg(B0,U), cfg(C0,
# 	T), assignment(D0), assignment(C0), ancestor(F0,U), ancestor(F0,
# 	Z), cfg(F0,H0), cfg(G0,V), voidPointer(H0).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:360,40,2,0 bug(A,B) :- assignment(B).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [12 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_135_f_loop_01_c_l_25_c_4_,bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_135_f_loop_01_c_l_25_c_4_,bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(A,E), ancestor(B,F), ancestor(B,G), ancestor(B,H), ancestor(B,I), cfg(A,J), cfg(B,K), assignment(A), assignment(B), writeToPointer(B), cfg(F,L), cfg(G,F), cfg(H,M), cfg(I,H), cfg(C,D), cfg(D,N), cfg(K,O), cfg(J,P), ref(F,Q), ref(G,R), ref(H,Q), ref(I,S), ref(K,Q), ref(J,R), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I), sizeOfInt(F), sizeOfInt(G), sizeOfInt(H), sizeOfInt(K), sizeOfInt(J), array10(G), array10(J), ancestor(N,C), cfg(L,B), cfg(N,A), cfg(M,G), cfg(P,T), cfg(O,U), ref(T,Q), ref(U,Q), ref(V,S), ref(W,S), ref(X,S), assignment(P), pointer(S), sizeOfInt(Q), sizeOfInt(R), array10(R), cfg(T,Y), cfg(U,Z), cfg(V,A0), cfg(W,C), cfg(X,B0), pointer(V), pointer(W), pointer(X), sizeOfInt(T), sizeOfInt(U), cfg(Z,C0), cfg(Y,D0), cfg(B0,E0), cfg(A0,F0), cfg(D0,U), cfg(E0,W), cfg(F0,G0), cfg(C0,I), cfg(C0,V), assignment(D0), assignment(E0), ancestor(G0,V), ancestor(G0,A0), cfg(G0,H0), voidPointer(H0).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
# 	F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J),
# 	assignment(A), assignment(B), writeToPointer(B), cfg(E,
# 	K), cfg(F,E), cfg(G,L), cfg(H,G), cfg(C,D), cfg(D,M),
# 	cfg(J,N), cfg(I,O), ref(E,P), ref(F,Q), ref(G,P), ref(H,
# 	R), ref(J,P), ref(I,Q), alloc(D), alloc_doesnt_check_sizeOf(D),
# 	pointer(H), sizeOfInt(E), sizeOfInt(F), sizeOfInt(G),
# 	sizeOfInt(J), sizeOfInt(I), array10(F), array10(I),
# 	ancestor(M,C), cfg(K,B), cfg(M,A), cfg(L,F), cfg(O,S),
# 	cfg(N,T), ref(S,P), ref(T,P), ref(U,R), ref(V,R), ref(W,
# 	R), assignment(O), pointer(R), sizeOfInt(P), sizeOfInt(Q),
# 	array10(Q), cfg(S,X), cfg(T,Y), cfg(U,Z), cfg(V,C),
# 	cfg(W,A0), pointer(U), pointer(V), pointer(W), sizeOfInt(S),
# 	sizeOfInt(T), cfg(Y,B0), cfg(X,C0), cfg(A0,D0), cfg(Z,
# 	E0), cfg(C0,T), cfg(D0,V), cfg(E0,F0), cfg(B0,H), cfg(B0,
# 	U), assignment(C0), assignment(D0), ancestor(F0,U), ancestor(F0,
# 	Z), cfg(F0,G0), voidPointer(G0).
#
# [C:379,400,20,0 bug(A,B).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(A,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- ancestor(B,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(A,C).]
# [C:378,400,20,0 bug(A,B) :- cfg(B,C).]
# [C:378,400,20,0 bug(A,B) :- assignment(A).]
# [C:360,40,2,0 bug(A,B) :- assignment(B).]
# [C:378,400,20,0 bug(A,B) :- writeToPointer(B).]
# [12 explored search nodes]
# f=379,p=400,n=20,h=0
# [No compression]
#
#
# [Total time taken 1.920s]

# %%
with open("../code/progol_input_test.pl", "w") as f:
    f.write(script)

# %% [markdown]
# Below are generated with settings:
#
# :- set(c,3)?
#
# :- set(i,3)?
#
# :- set(h,2000)?
#
# :- set(cover)?
#
# :- set(inflate,1500)?

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        """bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
	writeToPointer(B), cfg(C,D), cfg(D,J), cfg(E,F), cfg(F,
	K), cfg(G,E), cfg(H,L), cfg(I,M), ref(H,N), ref(I,O),
	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
	sizeOfInt(H), array10(H), ancestor(K,E), ancestor(J,
	C), cfg(K,B), cfg(M,P), cfg(J,A), cfg(L,Q), ref(Q,O),
	assignment(L), pointer(O), sizeOfInt(N), array10(N)."""
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        """bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,N),
	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
	pointer(H), ancestor(K,C), ancestor(J,E), cfg(K,A), 
	cfg(M,O), cfg(L,P), cfg(J,B), pointer(N)."""
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        """bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
	F), ancestor(B,G), ancestor(B,H), cfg(A,I), cfg(B,J),
	assignment(A), assignment(B), writeToPointer(B), cfg(C,
	D), cfg(D,K), cfg(E,L), cfg(F,E), cfg(G,M), cfg(H,G),
	cfg(I,N), cfg(J,O), ref(E,P), ref(F,Q), ref(G,P), ref(H,
	R), ref(I,Q), ref(J,P), alloc(D), alloc_doesnt_check_sizeOf(D),
	pointer(H), sizeOfInt(E), sizeOfInt(F), sizeOfInt(G),
	sizeOfInt(I), sizeOfInt(J), array10(F), array10(I), 
	ancestor(K,C), cfg(M,F), cfg(L,B), cfg(N,S), cfg(K,A),
	cfg(O,T), ref(S,P), ref(T,P), assignment(N), pointer(R),
	sizeOfInt(P), sizeOfInt(Q), array10(Q)."""
))

# %% [markdown]
# Below are generated with:
#
# :- set(c,5000)?
#
# :- set(i,5000)?
#
# :- set(h,5000)?
#
# :- set(cover)?
#
# :- set(inflate,1500)?

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        """bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
	sizeOfInt(H), array10(H), ancestor(J,E), ancestor(K,
	C), cfg(J,B), cfg(M,P), cfg(K,A), cfg(L,Q), ref(P,N),
	ref(R,O), ref(S,N), ref(T,N), assignment(M), pointer(N),
	sizeOfInt(O), array10(O), cfg(P,R), cfg(Q,U), cfg(R,
	G), cfg(S,C), cfg(T,V), pointer(P), pointer(S), pointer(T),
	sizeOfInt(R), array10(R), ancestor(U,I), ancestor(U,
	L), cfg(U,W), cfg(V,X), cfg(X,Y), assignment(X), voidPointer(W),
	cfg(Y,S)."""
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        """bug(A,B) :- ancestor(A,C), ancestor(A,D), ancestor(B,E), ancestor(B,
	F), ancestor(B,G), cfg(A,H), cfg(B,I), assignment(A),
	writeToPointer(B), cfg(E,F), cfg(F,J), cfg(G,E), cfg(C,
	D), cfg(D,K), cfg(I,L), cfg(H,M), ref(I,N), ref(H,O),
	sizeOf(F), alloc(D), alloc_doesnt_check_sizeOf(D), pointer(I),
	ancestor(J,E), ancestor(K,C), cfg(L,P), cfg(J,B), cfg(K,
	A), cfg(M,Q), ref(Q,O), ref(R,O), ref(S,N), ref(T,N),
	ref(U,N), pointer(N), cfg(Q,V), cfg(P,W), cfg(R,X), 
	cfg(S,Y), cfg(T,C), cfg(U,Z), pointer(S), pointer(T),
	pointer(U), ancestor(W,I), ancestor(W,L), cfg(W,A0),
	cfg(Y,G), cfg(Z,B0), cfg(V,C0), cfg(X,D0), ref(Y,E0),
	sizeOfInt(Y), array10(Y), cfg(D0,Q), cfg(B0,R), cfg(C0,
	T), cfg(C0,F0), ref(F0,E0), assignment(D0), assignment(B0),
	sizeOfInt(E0), array10(E0), voidPointer(A0), cfg(F0,
	G0), sizeOfInt(F0), array10(F0), cfg(G0,S), assignment(G0)."""
))
