# %% [markdown]
# # Exploring VDISC

# %%
# Run this cell iff you're in colab and need to setup your environment
# !git clone https://github.com/dj311/uob-summer-project.git

# Change working directory to be inside git repo, as if we were in a local jupyter in the project
import os
os.chdir('uob-summer-project')
# Out:
# Cloning into 'uob-summer-project'...
# remote: Enumerating objects: 8348, done.
# remote: Counting objects: 100% (8348/8348), done.
# remote: Compressing objects: 100% (668/668), done.
# remote: Total 8348 (delta 7724), reused 8250 (delta 7671), pack-reused 0
# Receiving objects: 100% (8348/8348), 3.30 MiB | 4.96 MiB/s, done.
# Resolving deltas: 100% (7724/7724), done.
# code  data  README.md  requirements.txt

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.12.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.16.4)

# %%
# Download the data set if you don't already have it

# !wget --output-document=./data/vdisc_train.hdf5 https://osf.io/6fexn/download
# !wget --output-document=./data/vdisc_test.hdf5 https://osf.io/f9t6z/download
# !wget --output-document=./data/vdisc_validate.hdf5 https://osf.io/43mzd/download
# Out:
# --2019-06-11 08:22:15--  https://osf.io/6fexn/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34ee71f01ef00170e4a90?action=download&version=1&direct [following]
# --2019-06-11 08:22:16--  https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34ee71f01ef00170e4a90?action=download&version=1&direct
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862111179 (822M) [application/octet-stream]
# Saving to: ‘./data/vdisc_train.hdf5’
#
# ./data/vdisc_train. 100%[===================>] 822.17M  34.8MB/s    in 21s
#
# 2019-06-11 08:22:38 (39.9 MB/s) - ‘./data/vdisc_train.hdf5’ saved [862111179/862111179]
#
# --2019-06-11 08:22:39--  https://osf.io/f9t6z/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e965603840019b1bdd2?action=download&version=1&direct [following]
# --2019-06-11 08:22:39--  https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e965603840019b1bdd2?action=download&version=1&direct
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 107870135 (103M) [application/octet-stream]
# Saving to: ‘./data/vdisc_test.hdf5’
#
# ./data/vdisc_test.h 100%[===================>] 102.87M  62.9MB/s    in 1.6s
#
# 2019-06-11 08:22:42 (62.9 MB/s) - ‘./data/vdisc_test.hdf5’ saved [107870135/107870135]
#
# --2019-06-11 08:22:43--  https://osf.io/43mzd/download
# Resolving osf.io (osf.io)... 35.190.84.173
# Connecting to osf.io (osf.io)|35.190.84.173|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e961f01ef00170e4a01?action=download&version=1&direct [following]
# --2019-06-11 08:22:43--  https://files.osf.io/v1/resources/d45bw/providers/osfstorage/5bf34e961f01ef00170e4a01?action=download&version=1&direct
# Resolving files.osf.io (files.osf.io)... 35.186.214.196
# Connecting to files.osf.io (files.osf.io)|35.186.214.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 108035556 (103M) [application/octet-stream]
# Saving to: ‘./data/vdisc_validate.hdf5’
#
# ./data/vdisc_valida 100%[===================>] 103.03M  6.14MB/s    in 17s
#
# 2019-06-11 08:23:01 (5.98 MB/s) - ‘./data/vdisc_validate.hdf5’ saved [108035556/108035556]

# %%
import h5py
import pandas as pd

# %%
cwes = set(open('data/combined-cwes.txt', 'r').read().strip().split('\n'))

# %%
vdisc_train_file = h5py.File('data/vdisc_train.hdf5')
vdisc_test_file = h5py.File('data/vdisc_test.hdf5')
vdisc_validate_file = h5py.File('data/vdisc_validate.hdf5')

# %%
def load_vdisc_to_pandas(vdisc_h45py):

    # Manually construct the data frame as a dict with key=<column name> and value=<list of
    # values for that column>.

    length = vdisc_h45py['functionSource'].size

    raw_dataframe = {
        'testcase_ID': ["vdisc_testcase_{}".format(index) for index in range(length)],
        'flaw_loc': [None]*length,
        'filename': [None]*length,
        'code': vdisc_h45py['functionSource'],
        'CWE-119': vdisc_h45py['CWE-119'],
        'CWE-120': vdisc_h45py['CWE-120'],
        'CWE-469': vdisc_h45py['CWE-469'],
        'CWE-476': vdisc_h45py['CWE-476'],
        'CWE-OTHERS': vdisc_h45py['CWE-other'],
    }

    empty_cwes = [
        cwe for cwe in cwes if cwe not in {
            'CWE-119',
            'CWE-120',
            'CWE-469',
            'CWE-476',
            'CWE-OTHERS',
        }
    ]

    for cwe in empty_cwes:
        raw_dataframe[cwe] = [False]*length


    return pd.DataFrame(data=raw_dataframe)

vdisc_train = load_vdisc_to_pandas(vdisc_train_file)
vdisc_test = load_vdisc_to_pandas(vdisc_test_file)
vdisc_validate = load_vdisc_to_pandas(vdisc_validate_file)

# %%
vdisc_train
# Out:
#                     testcase_ID flaw_loc filename  ... CWE-259  CWE-253  CWE-620
# 0              vdisc_testcase_0     None     None  ...   False    False    False
# 1              vdisc_testcase_1     None     None  ...   False    False    False
# 2              vdisc_testcase_2     None     None  ...   False    False    False
# 3              vdisc_testcase_3     None     None  ...   False    False    False
# 4              vdisc_testcase_4     None     None  ...   False    False    False
# 5              vdisc_testcase_5     None     None  ...   False    False    False
# 6              vdisc_testcase_6     None     None  ...   False    False    False
# 7              vdisc_testcase_7     None     None  ...   False    False    False
# 8              vdisc_testcase_8     None     None  ...   False    False    False
# 9              vdisc_testcase_9     None     None  ...   False    False    False
# 10            vdisc_testcase_10     None     None  ...   False    False    False
# 11            vdisc_testcase_11     None     None  ...   False    False    False
# 12            vdisc_testcase_12     None     None  ...   False    False    False
# 13            vdisc_testcase_13     None     None  ...   False    False    False
# 14            vdisc_testcase_14     None     None  ...   False    False    False
# 15            vdisc_testcase_15     None     None  ...   False    False    False
# 16            vdisc_testcase_16     None     None  ...   False    False    False
# 17            vdisc_testcase_17     None     None  ...   False    False    False
# 18            vdisc_testcase_18     None     None  ...   False    False    False
# 19            vdisc_testcase_19     None     None  ...   False    False    False
# 20            vdisc_testcase_20     None     None  ...   False    False    False
# 21            vdisc_testcase_21     None     None  ...   False    False    False
# 22            vdisc_testcase_22     None     None  ...   False    False    False
# 23            vdisc_testcase_23     None     None  ...   False    False    False
# 24            vdisc_testcase_24     None     None  ...   False    False    False
# 25            vdisc_testcase_25     None     None  ...   False    False    False
# 26            vdisc_testcase_26     None     None  ...   False    False    False
# 27            vdisc_testcase_27     None     None  ...   False    False    False
# 28            vdisc_testcase_28     None     None  ...   False    False    False
# 29            vdisc_testcase_29     None     None  ...   False    False    False
# ...                         ...      ...      ...  ...     ...      ...      ...
# 1019441  vdisc_testcase_1019441     None     None  ...   False    False    False
# 1019442  vdisc_testcase_1019442     None     None  ...   False    False    False
# 1019443  vdisc_testcase_1019443     None     None  ...   False    False    False
# 1019444  vdisc_testcase_1019444     None     None  ...   False    False    False
# 1019445  vdisc_testcase_1019445     None     None  ...   False    False    False
# 1019446  vdisc_testcase_1019446     None     None  ...   False    False    False
# 1019447  vdisc_testcase_1019447     None     None  ...   False    False    False
# 1019448  vdisc_testcase_1019448     None     None  ...   False    False    False
# 1019449  vdisc_testcase_1019449     None     None  ...   False    False    False
# 1019450  vdisc_testcase_1019450     None     None  ...   False    False    False
# 1019451  vdisc_testcase_1019451     None     None  ...   False    False    False
# 1019452  vdisc_testcase_1019452     None     None  ...   False    False    False
# 1019453  vdisc_testcase_1019453     None     None  ...   False    False    False
# 1019454  vdisc_testcase_1019454     None     None  ...   False    False    False
# 1019455  vdisc_testcase_1019455     None     None  ...   False    False    False
# 1019456  vdisc_testcase_1019456     None     None  ...   False    False    False
# 1019457  vdisc_testcase_1019457     None     None  ...   False    False    False
# 1019458  vdisc_testcase_1019458     None     None  ...   False    False    False
# 1019459  vdisc_testcase_1019459     None     None  ...   False    False    False
# 1019460  vdisc_testcase_1019460     None     None  ...   False    False    False
# 1019461  vdisc_testcase_1019461     None     None  ...   False    False    False
# 1019462  vdisc_testcase_1019462     None     None  ...   False    False    False
# 1019463  vdisc_testcase_1019463     None     None  ...   False    False    False
# 1019464  vdisc_testcase_1019464     None     None  ...   False    False    False
# 1019465  vdisc_testcase_1019465     None     None  ...   False    False    False
# 1019466  vdisc_testcase_1019466     None     None  ...   False    False    False
# 1019467  vdisc_testcase_1019467     None     None  ...   False    False    False
# 1019468  vdisc_testcase_1019468     None     None  ...   False    False    False
# 1019469  vdisc_testcase_1019469     None     None  ...   False    False    False
# 1019470  vdisc_testcase_1019470     None     None  ...   False    False    False
#
# [1019471 rows x 126 columns]

# %%
# Save this pandas dataframe as a csv for ease next time
vdisc_train.to_csv('data/vdisc_train.csv.gz')
vdisc_test.to_csv('data/vdisc_test.csv.gz')
vdisc_validate.to_csv('data/vdisc_validate.csv.gz')
