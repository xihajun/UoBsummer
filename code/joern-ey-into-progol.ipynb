# %% [markdown]
# # Joern-ey into Progol
#
# We have [generated](./generate_minimal_ilp_dataset.ipynb) a subset of the Juliet dataset consisting of small buffer overflow examples, and have [transformed](./Joern-ey%20into%20ILP.ipynb) each piece of source code into a a set of Prolog facts. In this notebook we generate Progol scripts from this dataset, and try to get it to learn rules to determine when a buffer overflow occurs.

# %% [markdown]
# ## Generating Progol
# In this section we load in the ILP dataset and its Progol representations, manually find the "error" node in each example, then define the `make_progol_script` function which will generate a script from the given testcase id's.

# %%
import pandas as pd

# %%
import tempfile
import subprocess
import graph_visualisation

# %%
ilp_data = pd.read_csv("../data/ilp_dataset.csv.gz")
ilp_data = ilp_data.drop("Unnamed: 0", axis=1)
ilp_data.head()
# Out:
#    testcase_ID                                           filename  \
# 0        62804  000/062/804/CWE121_Stack_Based_Buffer_Overflow...
# 1        62821  000/062/821/CWE121_Stack_Based_Buffer_Overflow...
# 2        62852  000/062/852/CWE121_Stack_Based_Buffer_Overflow...
# 3        62853  000/062/853/CWE121_Stack_Based_Buffer_Overflow...
# 4        62854  000/062/854/CWE121_Stack_Based_Buffer_Overflow...
#
#                                                 code     flaw  flaw_loc  \
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        35
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        30
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121        33
#
#      bug  code_length
# 0  False         1722
# 1  False         1808
# 2  False         1674
# 3  False         2396
# 4  False         2414

# %%
prolog = pd.read_csv("../data/ilp_prolog_data.csv.gz")
prolog = prolog.drop("Unnamed: 0", axis=1)
prolog.head()
# Out:
#    testcase_ID     flaw   bug  code_length  \
# 0      -232086  CWE-122  True         1625
# 1      -232012  CWE-122  True         1619
# 2       -62917  CWE-121  True         1622
# 3       -62916  CWE-121  True         1649
# 4       -62915  CWE-121  True         1638
#
#                                                 tree  \
# 0  % START: Generated Prolog\n% NODE PROPERTIES \...
# 1  % START: Generated Prolog\n% NODE PROPERTIES \...
# 2  % START: Generated Prolog\n% NODE PROPERTIES \...
# 3  % START: Generated Prolog\n% NODE PROPERTIES \...
# 4  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                           source_map
# 0  % CODE\nsource_code(bad_232086_id_1_f_l_c_, "p...
# 1  % CODE\nsource_code(bad_232012_id_0_f_l_c_, "p...
# 2  % CODE\nsource_code(bad_62917_id_0_f_l_c_, "p1...
# 3  % CODE\nsource_code(bad_62916_id_1_f_l_c_, "p1...
# 4  % CODE\nsource_code(bad_62915_id_0_f_l_c_, "p1...

# %%
juliet = pd.read_csv("../data/buffer_overflow_data.csv.gz")
juliet.drop("Unnamed: 0", axis=1)
juliet.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  testcase_ID  \
# 0         984           984        62516
# 1         985           985        62517
# 2         986           986        62518
# 3         987           987        62519
# 4         988           988        62520
#
#                                             filename  \
# 0  000/062/516/CWE121_Stack_Based_Buffer_Overflow...
# 1  000/062/517/CWE121_Stack_Based_Buffer_Overflow...
# 2  000/062/518/CWE121_Stack_Based_Buffer_Overflow...
# 3  000/062/519/CWE121_Stack_Based_Buffer_Overflow...
# 4  000/062/520/CWE121_Stack_Based_Buffer_Overflow...
#
#                                                 code     flaw  flaw_loc    bug
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       112  False
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117  False
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       117  False
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123  False
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...  CWE-121       123  False

# %%
prolog['source_code'] = ''
prolog['flaw_loc'] = 0
prolog['bad_code'] = ''

# %%
for i in range(len(prolog)):
    label = prolog.iloc[i].testcase_ID == juliet.testcase_ID
    prolog['source_code'].iloc[i] = juliet.loc[label].iloc[0].code
    prolog['flaw_loc'].iloc[i] = juliet.loc[label].iloc[0].flaw_loc
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
for i in range(len(prolog)):
    loc =  prolog.iloc[i].flaw_loc
    testcase_ID = prolog.iloc[i].testcase_ID
    if testcase_ID < 0:
        prolog['bad_code'].iloc[i] = prolog.iloc[i].source_code.split('\n')[loc-1].strip()[0:-1]
    else:
        prolog['bad_code'].iloc[i] = prolog.loc[prolog.testcase_ID == -testcase_ID].iloc[0].bad_code

# %%
prolog.head()
# Out:
#    testcase_ID     flaw   bug  code_length  \
# 0      -232086  CWE-122  True         1625
# 1      -232012  CWE-122  True         1619
# 2       -62917  CWE-121  True         1622
# 3       -62916  CWE-121  True         1649
# 4       -62915  CWE-121  True         1638
#
#                                                 tree  \
# 0  % START: Generated Prolog\n% NODE PROPERTIES \...
# 1  % START: Generated Prolog\n% NODE PROPERTIES \...
# 2  % START: Generated Prolog\n% NODE PROPERTIES \...
# 3  % START: Generated Prolog\n% NODE PROPERTIES \...
# 4  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                           source_map  \
# 0  % CODE\nsource_code(bad_232086_id_1_f_l_c_, "p...
# 1  % CODE\nsource_code(bad_232012_id_0_f_l_c_, "p...
# 2  % CODE\nsource_code(bad_62917_id_0_f_l_c_, "p1...
# 3  % CODE\nsource_code(bad_62916_id_1_f_l_c_, "p1...
# 4  % CODE\nsource_code(bad_62915_id_0_f_l_c_, "p1...
#
#                                          source_code  flaw_loc  \
# 0  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        31
# 1  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        31
# 2  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        32
# 3  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        34
# 4  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        34
#
#                                 bad_code
# 0  memmove(data, source, 10*sizeof(int))
# 1   memcpy(data, source, 10*sizeof(int))
# 2  memmove(data, source, 10*sizeof(int))
# 3  memmove(data, source, 10*sizeof(int))
# 4  memmove(data, source, 10*sizeof(int))

# %%
good_examples = prolog[prolog['bug'] == False]
bad_examples = prolog[prolog['bug'] == True]

# %%
good_examples.head()
# Out:
#     testcase_ID     flaw    bug  code_length  \
# 20        62804  CWE-121  False         1722
# 21        62821  CWE-121  False         1808
# 22        62852  CWE-121  False         1674
# 23        62853  CWE-121  False         2396
# 24        62854  CWE-121  False         2414
#
#                                                  tree  \
# 20  % START: Generated Prolog\n% NODE PROPERTIES \...
# 21  % START: Generated Prolog\n% NODE PROPERTIES \...
# 22  % START: Generated Prolog\n% NODE PROPERTIES \...
# 23  % START: Generated Prolog\n% NODE PROPERTIES \...
# 24  % START: Generated Prolog\n% NODE PROPERTIES \...
#
#                                            source_map  \
# 20  % CODE\nsource_code(good_62804_id_1_f_l_c_, "p...
# 21  % CODE\nsource_code(good_62821_id_1_f_l_58_c_1...
# 22  % CODE\nsource_code(good_62852_id_0_f_l_c_, "p...
# 23  % CODE\nsource_code(good_62853_id_1_f_l_c_, "p...
# 24  % CODE\nsource_code(good_62854_id_1_f_l_c_, "p...
#
#                                           source_code  flaw_loc  \
# 20  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 21  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        35
# 22  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        30
# 23  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
# 24  /* TEMPLATE GENERATED TESTCASE FILE\nFilename:...        33
#
#                                 bad_code
# 20                   data[i] = source[i]
# 21                   data[i] = source[i]
# 22  memcpy(data, source, 10*sizeof(int))
# 23  memcpy(data, source, 10*sizeof(int))
# 24  memcpy(data, source, 10*sizeof(int))

# %%
def extract_node_ids(tree):
    nodes = set()
    
    in_ast_section = False
    
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% AST':
            in_ast_section = True
        
        if line == '% CFG':
            in_ast_section = False
            
        if line == '% REF':
            in_ast_section = False
        
        if in_ast_section and not line.startswith("%"):
            parent, child = line[4:-2].split(", ")
            nodes.add(parent)
            nodes.add(child)
            
    return nodes

# %%
# good nodes_g
nodes_g = set()

for i in range(len(good_examples)):
    good_nodes = extract_node_ids(good_examples.iloc[i].tree)
    nodes_g = set.union(nodes_g,good_nodes)

    
# bad nodes_b
nodes_b = set()

for i in range(len(bad_examples)):
    bad_nodes = extract_node_ids(bad_examples.iloc[i].tree)
    nodes_b = set.union(nodes_b,bad_nodes)

nodes = set.union(nodes_g,nodes_b)

# %% [markdown]
# Manually find the "error" node for each testcase, and tag those as the positive or  negative examples.

# %%
print(bad_examples.source_map.iloc[0])
# Out:
# % CODE
# source_code(bad_232086_id_1_f_l_c_, "p1").
# source_code(bad_232086_id_2_f_l_48_c_9_, "int argc").
# source_code(bad_232086_id_3_f_l_c_, "p1").
# source_code(bad_232086_id_4_f_l_c_, "p2").
# source_code(bad_232086_id_5_f_l_c_, "p2").
# source_code(bad_232086_id_6_f_l_48_c_19_, "char * argv[]").
# source_code(bad_232086_id_7_f_l_c_, "p1").
# source_code(bad_232086_id_8_f_l_c_, "p2").
# source_code(bad_232086_id_9_f_l_c_, "p2").
# source_code(bad_232086_id_10_f_l_c_, "p2").
# source_code(bad_232086_id_11_f_l_c_, "p1").
# source_code(bad_232086_id_12_f_l_c_, "p1").
# source_code(bad_232086_id_13_f_l_c_, "p1").
# source_code(bad_232086_id_14_f_l_c_, "p1").
# source_code(bad_232086_id_15_f_l_c_, "p1").
# source_code(bad_232086_id_16_f_l_c_, "p1").
# source_code(bad_232086_id_17_f_l_c_, "p2").
# source_code(bad_232086_id_18_f_l_c_, "p1").
# source_code(bad_232086_id_19_f_l_c_, "p1").
# source_code(bad_232086_id_20_f_l_c_, "p1").
# source_code(bad_232086_id_21_f_l_c_, "p1").
# source_code(bad_232086_id_22_f_l_c_, "p1").
# source_code(bad_232086_id_23_f_l_c_, "p3").
# source_code(bad_232086_id_24_f_l_c_, "p1").
# source_code(bad_232086_id_25_f_l_c_, "RET").
# source_code(bad_232086_id_27_f_l_c_, "p1").
# source_code(bad_232086_id_28_f_l_c_, "p1").
# source_code(bad_232086_id_29_f_l_c_, "RET").
# source_code(bad_232086_id_31_f_l_c_, "RET").
# source_code(bad_232086_id_32_f_l_c_, "p1").
# source_code(bad_232086_id_35_f_l_c_, "p3").
# source_code(bad_232086_id_37_f_l_c_, "RET").
# source_code(bad_232086_id_38_f_l_c_, "").
# source_code(bad_232086_id_39_f_l_c_, "p1").
# source_code(bad_232086_id_41_f_l_c_, "").
# source_code(bad_232086_id_42_f_l_c_, "p1").
# source_code(bad_232086_id_44_f_l_c_, "p1").
# source_code(bad_232086_id_45_f_l_c_, "p2").
# source_code(bad_232086_id_46_f_l_c_, "p1").
# source_code(bad_232086_id_47_f_l_c_, "RET").
# source_code(bad_232086_id_48_f_l_c_, "p2").
# source_code(bad_232086_id_51_f_l_c_, "").
# source_code(bad_232086_id_52_f_l_c_, "p1").
# source_code(bad_232086_id_53_f_l_c_, "RET").
# source_code(bad_232086_id_54_f_l_c_, "").
# source_code(bad_232086_id_55_f_l_c_, "").
# source_code(bad_232086_id_56_f_l_c_, "RET").
# source_code(bad_232086_id_58_f_l_c_, "RET").
# source_code(bad_232086_id_59_f_l_c_, "").
# source_code(bad_232086_id_60_f_l_c_, "p2").
# source_code(bad_232086_id_61_f_l_c_, "p1").
# source_code(bad_232086_id_62_f_l_c_, "p2").
# source_code(bad_232086_id_63_f_l_c_, "p1").
# source_code(bad_232086_id_64_f_l_c_, "").
# source_code(bad_232086_id_65_f_l_c_, "p2").
# source_code(bad_232086_id_66_f_l_c_, "RET").
# source_code(bad_232086_id_67_f_l_c_, "p1").
# source_code(bad_232086_id_68_f_l_c_, "RET").
# source_code(bad_232086_id_69_f_l_c_, "").
# source_code(bad_232086_id_70_f_l_c_, "RET").
# source_code(bad_232086_id_71_f_l_c_, "").
# source_code(bad_232086_id_72_f_l_c_, "").
# source_code(bad_232086_id_73_f_l_c_, "RET").
# source_code(bad_232086_id_74_f_l_c_, "p1").
# source_code(bad_232086_id_76_f_l_c_, "").
# source_code(bad_232086_id_77_f_l_c_, "p1").
# source_code(bad_232086_id_78_f_l_c_, "RET").
# source_code(bad_232086_id_79_f_l_c_, "").
# source_code(bad_232086_id_80_f_l_c_, "").
# source_code(bad_232086_id_82_f_l_c_, "").
# source_code(bad_232086_id_83_f_l_c_, "p1").
# source_code(bad_232086_id_84_f_l_c_, "p2").
# source_code(bad_232086_id_85_f_l_c_, "RET").
# source_code(bad_232086_id_86_f_l_c_, "p1").
# source_code(bad_232086_id_88_f_l_c_, "").
# source_code(bad_232086_id_89_f_l_c_, "RET").
# source_code(bad_232086_id_101_f_memmove_01_c_l_56_c_11_, "0").
# source_code(bad_232086_id_102_f_memmove_01_c_l_56_c_4_, "return 0;").
# source_code(bad_232086_id_103_f_memmove_01_c_l_54_c_14_, ""Finished bad()"").
# source_code(bad_232086_id_104_f_memmove_01_c_l_54_c_4_, "printLine("Finished bad()")").
# source_code(bad_232086_id_106_f_memmove_01_c_l_53_c_4_, "CWE122_Heap_Based_Buffer_Overflow__CWE131_memmove_01_bad()").
# source_code(bad_232086_id_107_f_memmove_01_c_l_52_c_14_, ""Calling bad()..."").
# source_code(bad_232086_id_109_f_memmove_01_c_l_52_c_4_, "printLine("Calling bad()...")").
# source_code(bad_232086_id_110_f_memmove_01_c_l_50_c_26_, "NULL").
# source_code(bad_232086_id_112_f_memmove_01_c_l_50_c_21_, "time(NULL)").
# source_code(bad_232086_id_113_f_memmove_01_c_l_50_c_12_, "unsigned").
# source_code(bad_232086_id_114_f_memmove_01_c_l_50_c_11_, "(unsigned)time(NULL)").
# source_code(bad_232086_id_116_f_memmove_01_c_l_50_c_4_, "srand( (unsigned)time(NULL) )").
# source_code(bad_232086_id_117_f_memmove_01_c_l_49_c_0_, "").
# source_code(bad_232086_id_118_f_l_48_c_0_, "RET").
# source_code(bad_232086_id_119_f_l_48_c_19_, "char * argv[]").
# source_code(bad_232086_id_120_f_l_48_c_9_, "int argc").
# source_code(bad_232086_id_127_f_memmove_01_c_l_32_c_13_, "data").
# source_code(bad_232086_id_129_f_memmove_01_c_l_32_c_8_, "free(data)").
# source_code(bad_232086_id_130_f_memmove_01_c_l_31_c_26_, "0").
# source_code(bad_232086_id_131_f_memmove_01_c_l_31_c_21_, "data").
# source_code(bad_232086_id_133_f_memmove_01_c_l_31_c_21_, "data[0]").
# source_code(bad_232086_id_135_f_memmove_01_c_l_31_c_8_, "printIntLine(data[0])").
# source_code(bad_232086_id_136_f_memmove_01_c_l_30_c_40_, "int").
# source_code(bad_232086_id_138_f_memmove_01_c_l_30_c_33_, "sizeof(int)").
# source_code(bad_232086_id_139_f_memmove_01_c_l_30_c_30_, "10").
# source_code(bad_232086_id_141_f_memmove_01_c_l_30_c_30_, "10*sizeof(int)").
# source_code(bad_232086_id_142_f_memmove_01_c_l_30_c_22_, "source").
# source_code(bad_232086_id_143_f_memmove_01_c_l_30_c_16_, "data").
# source_code(bad_232086_id_145_f_memmove_01_c_l_30_c_8_, "memmove(data, source, 10*sizeof(int))").
# source_code(bad_232086_id_146_f_memmove_01_c_l_28_c_12_, "source").
# source_code(bad_232086_id_147_f_memmove_01_c_l_28_c_12_, "source[10] = {0}").
# source_code(bad_232086_id_148_f_l_c_, "source").
# source_code(bad_232086_id_149_f_memmove_01_c_l_28_c_8_, "").
# source_code(bad_232086_id_150_f_memmove_01_c_l_26_c_29_, "1").
# source_code(bad_232086_id_152_f_memmove_01_c_l_26_c_28_, "-1").
# source_code(bad_232086_id_154_f_memmove_01_c_l_26_c_23_, "exit(-1)").
# source_code(bad_232086_id_155_f_memmove_01_c_l_26_c_22_, "").
# source_code(bad_232086_id_156_f_memmove_01_c_l_26_c_16_, "NULL").
# source_code(bad_232086_id_157_f_memmove_01_c_l_26_c_8_, "data").
# source_code(bad_232086_id_159_f_memmove_01_c_l_26_c_8_, "data == NULL").
# source_code(bad_232086_id_160_f_memmove_01_c_l_26_c_4_, "if (data == NULL)").
# source_code(bad_232086_id_161_f_memmove_01_c_l_25_c_25_, "10").
# source_code(bad_232086_id_163_f_memmove_01_c_l_25_c_18_, "malloc(10)").
# source_code(bad_232086_id_164_f_memmove_01_c_l_25_c_12_, "int *").
# source_code(bad_232086_id_166_f_memmove_01_c_l_25_c_11_, "(int *)malloc(10)").
# source_code(bad_232086_id_167_f_memmove_01_c_l_25_c_4_, "data").
# source_code(bad_232086_id_168_f_memmove_01_c_l_25_c_4_, "data = (int *)malloc(10)").
# source_code(bad_232086_id_169_f_memmove_01_c_l_23_c_11_, "NULL").
# source_code(bad_232086_id_170_f_memmove_01_c_l_23_c_4_, "data").
# source_code(bad_232086_id_172_f_memmove_01_c_l_23_c_4_, "data = NULL").
# source_code(bad_232086_id_173_f_l_c_, "data").
# source_code(bad_232086_id_174_f_memmove_01_c_l_22_c_0_, "").
# source_code(bad_232086_id_175_f_l_21_c_0_, "RET").
# source_code(bad_232086_id_177_f_l_50_c_, "/* seed randomness */").
# source_code(id_178_f_l_40_c_, "/* Below is the main(). It is only used when building this testcase on
#  * its own for testing or for building a binary to use in testing binary
#  * analysis tools. It is not used when compiling all the testcases as one
#  * application, which is how source code analysis tools are tested.
#  */").
# source_code(bad_232086_id_179_f_l_30_c_, "/* POTENTIAL FLAW: Possible buffer overflow if data was not allocated correctly in the source */").
# source_code(bad_232086_id_180_f_l_25_c_, "/* FLAW: Allocate memory without using sizeof(int) */").
# source_code(id_181_f_l_6_c_, "/*
#  * @description
#  * CWE: 122 Heap Based Buffer Overflow
#  * BadSource:  Allocate memory without using sizeof(int)
#  * GoodSource: Allocate memory using sizeof(int)
#  * Sink: memmove
#  *    BadSink : Copy array to data using memmove()
#  * Flow Variant: 01 Baseline
#  *
#  * */").
# source_code(id_182_f_l_1_c_, "/* TEMPLATE GENERATED TESTCASE FILE
# Filename: CWE122_Heap_Based_Buffer_Overflow__CWE131_memmove_01.c
# Label Definition File: CWE122_Heap_Based_Buffer_Overflow__CWE131.label.xml
# Template File: sources-sink-01.tmpl.c
# */").

# %%
def find_bug_id(good_examples, i = 0):
    
    tree = good_examples.source_map.iloc[i]
    parents = []
    children = []
    in_code_section = False
    temp = 0
    for line in tree.split('\n'):
        line = line.strip()
        
        if line == '% CODE':
            in_code_section = True
        
        if in_code_section and not line.startswith("%"):
            try:
                #import pdb; pdb.set_trace()
                parent, child = line[12:-3].split(', "')
                parents.append(parent)
                children.append(child)
            except:
                temp +=1
    zipbObj = zip(children, parents)
    bug_node = dict(zipbObj)
    
    loc = good_examples.iloc[i].flaw_loc
    source_code = good_examples.iloc[i].bad_code

    return bug_node[source_code]

# %%
find_bug_id(bad_examples,1)
# Out:
# 'bad_232012_id_145_f_memcpy_01_c_l_30_c_8_'

# %%
bad_node = []
good_node = []
for i in range(20):
    bad_node.append(find_bug_id(bad_examples,i))
    good_node.append(find_bug_id(good_examples,i))

# %%
types = [
    'node('+node_id+').' for node_id in nodes
]

positive_examples = [
    'bug('+node_id+').' for node_id in bad_node
]

negative_examples = [
    ':- bug('+node_id+').' for node_id in good_node
]

# %%
def make_progol_script(header, testcases, types=types, positive_examples=positive_examples, negative_examples=negative_examples):
    script_template = """
{header}

%% Types
{types}

%% background knowledge
{bg_knowledge}

%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """

    script = script_template.format(
        header = header,
        types = '\n'.join(types),
        bg_knowledge = '\n'.join(prolog['tree']),
        positive_examples='\n'.join(positive_examples),
        negative_examples='\n'.join(negative_examples),
    )
    
    # remove all lines not related to this testcase
    script = '\n'.join([
        line for line in script.split("\n")  if any(
            str(testcase) in line for testcase in testcases
        ) or not ("good_" in line or "bad_" in line)
    ])
    
    return script

# %% [markdown]
# ## Experimentation
# In this section we try different subsets of the dataset with different Progol settings.

# %% [markdown]
# We try by setting the following header:

# %%
header = """
% Settings
:- set(c,30)?
:- set(i,30)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

"""

#void is a pointer to something left unspecified

script = make_progol_script(header, {62852,
    62900,
    62869,
    62804,
    232012,
    62853,
    62917,
    232086,
    62901,
    62854,
    62867,
    62902,
    62915,
    62868,
    62861,
    62916,
    62909,
    62865,
    62913,
    62821,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(100,pointer(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOfInt(+node))? - Time taken 0.00s]
# [:- modeb(100,array10(+node))? - Time taken 0.00s]
# [:- modeb(100,voidPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), pointer(M), pointer(N), sizeOfInt(O), array10(O).
# [Most-specific clause reduced by 14 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), pointer(N), pointer(O), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 14 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_121_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_121_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62916_id_133_f_memmove_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62916_id_133_f_memmove_17_c_l_33_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62915_id_121_f_memmove_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62915_id_121_f_memmove_16_c_l_33_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62913_id_127_f_memmove_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62913_id_127_f_memmove_14_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62909_id_121_f_memmove_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62909_id_121_f_memmove_10_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62902_id_127_f_memmove_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62902_id_127_f_memmove_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(J), pointer(K), pointer(L), sizeOfInt(M), array10(M).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), pointer(D), sizeOfInt(C), array10(C), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E), pointer(H), sizeOfInt(G), array10(G), pointer(K), pointer(L), pointer(M), sizeOfInt(J), array10(J).
# [Most-specific clause reduced by 10 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,
# 	E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C),
# 	ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,90,18,0 bug(A) :- writeToPointer(A).]
# [5 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62821_id_110_f_loop_18_c_l_34_c_12_).]
# [Generalising <bug(bad_62821_id_110_f_loop_18_c_l_34_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(D,H), ref(E,I), ref(F,H), ref(G,J), pointer(G), sizeOfInt(D), sizeOfInt(E), sizeOfInt(F), array10(E), ref(K,H), ref(L,H), ref(M,H), ref(N,I), ref(O,J), ref(P,J), ref(Q,J), pointer(J), sizeOfInt(I), sizeOfInt(H), array10(I), pointer(O), pointer(P), pointer(Q), sizeOfInt(K), sizeOfInt(L), sizeOfInt(M), sizeOfInt(N), array10(N).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,
# 	E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C),
# 	ref(D,H), ref(E,I), ref(F,H), ref(G,J), pointer(G),
# 	sizeOfInt(D), sizeOfInt(E), sizeOfInt(F), array10(E),
# 	pointer(J), sizeOfInt(I), sizeOfInt(H), array10(I).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:60,10,2,0 bug(A) :- assignment(A).]
# [4 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(D,H), ref(E,I), ref(F,H), ref(G,J), pointer(G), sizeOfInt(D), sizeOfInt(E), sizeOfInt(F), array10(E), ref(K,I), ref(L,J), ref(M,J), ref(N,J), ref(O,H), ref(P,H), ref(Q,H), pointer(J), sizeOfInt(H), sizeOfInt(I), array10(I), pointer(L), pointer(M), pointer(N), sizeOfInt(K), sizeOfInt(O), sizeOfInt(P), sizeOfInt(Q), array10(K).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,
# 	E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C),
# 	ref(D,H), ref(E,I), ref(F,H), ref(G,J), pointer(G),
# 	sizeOfInt(D), sizeOfInt(E), sizeOfInt(F), array10(E),
# 	pointer(J), sizeOfInt(H), sizeOfInt(I), array10(I).
#
# [C:79,100,20,0 bug(A).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:78,100,20,0 bug(A) :- ast(A,B).]
# [C:60,10,2,0 bug(A) :- assignment(A).]
# [4 explored search nodes]
# f=79,p=100,n=20,h=0
# [No compression]
#
#
# [Total time taken 0.700s]

# %% [markdown]
# (This is from 5 examples, without the method features).
#
# This creates one rule per example, but is unable to create a general one. These rules succinctly describe the situation, and three of the examples have the same rule!
#
# ```
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C, E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), ast(A,C), ast(B,D), ref(C,E), ast(D,F), sizeOf(D).
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B), ref(C,D).
# ```

# %% [markdown]
# The first rules are generated for all buffer overflows which make use of a bulk memory operation (e.g. `memcpy` and `memmove`) whilst the last rule is for the examples where an array is copied item by item.
#
# What do these rules mean? Let's visualise them to find out:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,E), ast(D,F), sizeOf(D)."
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B), ref(C,D)."
))

# %% [markdown]
# Visualising the new rules from 20 examples with method properties added in:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ref(C,F), ref(D,G), pointer(D), sizeOfInt(C), array10(C), ast(E,H), sizeOf(E), pointer(G), sizeOfInt(F), array10(F)."
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(D,H), ref(E,I), ref(F,H), ref(G,J), pointer(G), sizeOfInt(D), sizeOfInt(E), sizeOfInt(F), array10(E), pointer(J), sizeOfInt(I), sizeOfInt(H), array10(I)."

))

# %% [markdown]
# **Question:** Can ILP learn logical or's? And so could these three rules be considered in composite?
#
# **Question:** Can we create probabilistic model from these rules?

# %%
script = make_progol_script("""
% Settings
:- set(c,40)?
:- set(i,40)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,200)?
:- set(noise,0.2)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, cfg(+node,-node))?
:- modeb(*, cfg(-node,+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))? 


:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))? """, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,40)? - Time taken 0.00s]
# [:- set(i,40)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,200)? - Time taken 0.00s]
# [:- set(noise,0.200)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,Q), cfg(Y,R), cfg(Z,P), cfg(A0,M), cfg(B0,M), compMemberAccess(N), ast(S,N), ast(T,O), ast(X,R), ast(X,W), ast(Y,C0), ast(Y,D0), ast(Z,Q), ast(Z,E0), ast(A0,F0), ast(B0,P), ast(B0,U), cfg(V,G0), cfg(W,X), cfg(U,B0), cfg(T,D0), cfg(B0,H0), cfg(F0,A0), cfg(E0,Z), ref(I0,Y), assignment(X), assignment(Z), ast(F0,H0), ast(C0,K), ast(C0,X), ast(C0,Z), ast(C0,J0), ast(C0,K0), ast(E0,G0), ast(E0,L0), ast(G0,V), cfg(H0,F0), cfg(G0,E0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,J), ast(J0,S), ast(J0,T), ast(K0,B0), ast(K0,M0), ast(M0,A0).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I),
# 	sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,
# 	U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,Q), cfg(Y,R),
# 	cfg(Z,P), cfg(A0,M), cfg(B0,M), compMemberAccess(N),
# 	ast(S,N), ast(T,O), ast(X,R), ast(X,W), ast(Y,C0), ast(Y,
# 	D0), ast(Z,Q), ast(Z,E0), ast(A0,F0), ast(B0,P), ast(B0,
# 	U), cfg(V,G0), cfg(W,X), cfg(U,B0), cfg(T,D0), cfg(B0,
# 	H0), cfg(F0,A0), cfg(E0,Z), ref(I0,Y), assignment(X),
# 	assignment(Z), ast(F0,H0), ast(C0,K), ast(C0,X), ast(C0,
# 	Z), ast(C0,J0), ast(C0,K0), ast(E0,G0), ast(G0,V), cfg(H0,
# 	F0), cfg(G0,E0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,
# 	J), ast(J0,S), ast(J0,T), ast(K0,B0), ast(K0,L0), ast(L0,
# 	A0).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,R), cfg(Y,Q), cfg(Z,M), cfg(A0,M), cfg(B0,P), compMemberAccess(N), ast(S,N), ast(T,O), ast(X,C0), ast(X,D0), ast(Y,R), ast(Y,W), ast(Z,E0), ast(A0,P), ast(A0,U), ast(B0,Q), ast(B0,F0), cfg(W,Y), cfg(V,G0), cfg(T,D0), cfg(U,A0), cfg(A0,H0), cfg(E0,Z), cfg(F0,B0), ref(I0,X), assignment(Y), assignment(B0), ast(E0,H0), ast(C0,K), ast(C0,Y), ast(C0,B0), ast(C0,J0), ast(C0,K0), ast(F0,G0), ast(F0,L0), ast(G0,V), cfg(G0,F0), cfg(H0,E0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,J), ast(J0,S), ast(J0,T), ast(K0,A0), ast(K0,M0), ast(M0,Z).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), ref(Q,K), ref(R,K), assignment(I),
# 	sizeOf(F), ast(N,E), ast(N,H), cfg(N,S), cfg(O,T), cfg(P,
# 	U), cfg(Q,V), cfg(R,W), cfg(S,O), cfg(X,R), cfg(Y,Q),
# 	cfg(Z,M), cfg(A0,M), cfg(B0,P), compMemberAccess(N),
# 	ast(S,N), ast(T,O), ast(X,C0), ast(X,D0), ast(Y,R),
# 	ast(Y,W), ast(Z,E0), ast(A0,P), ast(A0,U), ast(B0,Q),
# 	ast(B0,F0), cfg(W,Y), cfg(V,G0), cfg(T,D0), cfg(U,A0),
# 	cfg(A0,H0), cfg(E0,Z), cfg(F0,B0), ref(I0,X), assignment(Y),
# 	assignment(B0), ast(E0,H0), ast(C0,K), ast(C0,Y), ast(C0,
# 	B0), ast(C0,J0), ast(C0,K0), ast(F0,G0), ast(G0,V), cfg(G0,
# 	F0), cfg(H0,E0), alloc(G0), ast(J0,A), ast(J0,I), ast(J0,
# 	J), ast(J0,S), ast(J0,T), ast(K0,A0), ast(K0,L0), ast(L0,
# 	Z).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,O), ast(T,W), ast(U,X), ast(U,Y), cfg(S,Z), cfg(Q,Y), cfg(R,A0), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T), ast(W,A0), ast(W,C0), ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,D0), ast(X,E0), ast(Z,P), ast(Z,S), ast(A0,R), cfg(A0,W), assignment(Z), alloc(A0), ast(D0,A), ast(D0,I), ast(D0,J), ast(D0,Q).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(U,P), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,
# 	O), ast(T,W), ast(U,X), ast(U,Y), cfg(S,Z), cfg(Q,Y),
# 	cfg(R,A0), cfg(W,T), cfg(Z,V), ref(B0,U), assignment(T),
# 	ast(W,A0), ast(X,K), ast(X,T), ast(X,V), ast(X,Z), ast(X,
# 	C0), ast(Z,P), ast(Z,S), ast(A0,R), cfg(A0,W), assignment(Z),
# 	alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(U,W), ast(U,X), ast(V,O), ast(V,Y), cfg(R,Z), cfg(Q,X), cfg(S,A0), cfg(Y,V), cfg(A0,T), ref(B0,U), assignment(V), ast(Y,Z), ast(Y,C0), ast(W,K), ast(W,A0), ast(W,D0), ast(W,E0), ast(Z,R), ast(A0,P), ast(A0,S), cfg(Z,Y), assignment(A0), alloc(Z), ast(D0,A), ast(D0,I), ast(D0,J), ast(D0,Q), ast(E0,T), ast(E0,F0), ast(F0,V).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,
# 	N), ast(U,W), ast(U,X), ast(V,O), ast(V,Y), cfg(R,Z),
# 	cfg(Q,X), cfg(S,A0), cfg(Y,V), cfg(A0,T), ref(B0,U),
# 	assignment(V), ast(Y,Z), ast(W,K), ast(W,A0), ast(W,
# 	C0), ast(W,D0), ast(Z,R), ast(A0,P), ast(A0,S), cfg(Z,
# 	Y), assignment(A0), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,
# 	J), ast(C0,Q), ast(D0,T), ast(D0,E0), ast(E0,V).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P), cfg(U,M), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(U,O), ast(U,Y), ast(V,P), ast(V,S), cfg(S,V), cfg(Q,X), cfg(R,Z), cfg(Y,U), ref(A0,T), assignment(U), assignment(V), ast(Y,Z), ast(Y,B0), ast(W,K), ast(W,U), ast(W,V), ast(W,C0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(L,F), cfg(M,I), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P),
# 	cfg(U,M), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,
# 	W), ast(T,X), ast(U,O), ast(U,Y), ast(V,P), ast(V,S),
# 	cfg(S,V), cfg(Q,X), cfg(R,Z), cfg(Y,U), ref(A0,T), assignment(U),
# 	assignment(V), ast(Y,Z), ast(W,K), ast(W,U), ast(W,V),
# 	ast(W,B0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(B0,A),
# 	ast(B0,I), ast(B0,J), ast(B0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P), cfg(U,O), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(V,O), ast(V,Y), cfg(Q,X), cfg(S,Z), cfg(R,A0), cfg(Y,V), cfg(Z,U), ref(B0,T), assignment(V), ast(W,K), ast(W,U), ast(W,V), ast(W,Z), ast(W,C0), ast(W,D0), ast(Y,A0), ast(Y,E0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,Y), assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P),
# 	cfg(U,O), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,
# 	W), ast(T,X), ast(V,O), ast(V,Y), cfg(Q,X), cfg(S,Z),
# 	cfg(R,A0), cfg(Y,V), cfg(Z,U), ref(B0,T), assignment(V),
# 	ast(W,K), ast(W,U), ast(W,V), ast(W,Z), ast(W,C0), ast(Y,
# 	A0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,Y), assignment(Z),
# 	alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M), cfg(T,O), cfg(U,M), cfg(V,P), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(U,O), ast(U,Y), ast(V,Z), ast(V,A0), cfg(R,B0), cfg(Q,A0), cfg(S,C0), cfg(Y,U), cfg(W,T), ref(D0,V), assignment(U), ast(Y,B0), ast(Y,E0), ast(Z,K), ast(Z,C0), ast(Z,F0), ast(Z,G0), ast(B0,R), ast(C0,P), ast(C0,S), cfg(X,W), cfg(B0,Y), cfg(C0,X), assignment(C0), alloc(B0), ast(F0,A), ast(F0,I), ast(F0,J), ast(F0,Q), ast(G0,T), ast(G0,H0), ast(H0,U).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,M),
# 	cfg(T,O), cfg(U,M), cfg(V,P), compMemberAccess(N), ast(Q,
# 	N), ast(T,W), ast(T,X), ast(U,O), ast(U,Y), ast(V,Z),
# 	ast(V,A0), cfg(R,B0), cfg(Q,A0), cfg(S,C0), cfg(Y,U),
# 	cfg(W,T), ref(D0,V), assignment(U), ast(Y,B0), ast(Z,
# 	K), ast(Z,C0), ast(Z,E0), ast(Z,F0), ast(B0,R), ast(C0,
# 	P), ast(C0,S), cfg(X,W), cfg(B0,Y), cfg(C0,X), assignment(C0),
# 	alloc(B0), ast(E0,A), ast(E0,I), ast(E0,J), ast(E0,Q),
# 	ast(F0,T), ast(F0,G0), ast(G0,U).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P), cfg(U,M), cfg(V,M), cfg(V,O), compMemberAccess(N), ast(Q,N), ast(T,W), ast(T,X), ast(U,O), ast(U,Y), cfg(Q,X), cfg(S,Z), cfg(R,A0), cfg(Y,U), cfg(Z,V), ref(B0,T), assignment(U), ast(W,K), ast(W,Z), ast(W,C0), ast(W,D0), ast(Y,A0), ast(Y,E0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,Y), assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q), ast(D0,V), ast(D0,F0), ast(F0,U).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,P),
# 	cfg(U,M), cfg(V,M), cfg(V,O), compMemberAccess(N), ast(Q,
# 	N), ast(T,W), ast(T,X), ast(U,O), ast(U,Y), cfg(Q,X),
# 	cfg(S,Z), cfg(R,A0), cfg(Y,U), cfg(Z,V), ref(B0,T),
# 	assignment(U), ast(W,K), ast(W,Z), ast(W,C0), ast(W,D0),
# 	ast(Y,A0), ast(A0,R), ast(Z,P), ast(Z,S), cfg(A0,Y),
# 	assignment(Z), alloc(A0), ast(C0,A), ast(C0,I), ast(C0,
# 	J), ast(C0,Q), ast(D0,V), ast(D0,E0), ast(E0,U).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A), ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L), ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O), cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,P), ast(T,S), ast(U,W), ast(U,X), ast(V,O), ast(V,Y), cfg(Q,X), cfg(R,Z), cfg(S,T), cfg(Y,V), ref(A0,U), assignment(T), assignment(V), ast(Y,Z), ast(Y,B0), ast(W,K), ast(W,T), ast(W,V), ast(W,C0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(C0,A), ast(C0,I), ast(C0,J), ast(C0,Q).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), cfg(A,E), cfg(B,A), writeToPointer(A),
# 	ast(B,F), ast(B,G), cfg(C,G), cfg(D,C), cfg(E,H), cfg(F,
# 	B), cfg(I,D), ref(C,J), ref(D,K), ref(E,K), ast(F,L),
# 	ast(I,M), cfg(G,L), cfg(H,N), cfg(M,I), cfg(L,F), ref(M,
# 	J), ref(O,K), ref(P,K), assignment(I), sizeOf(F), ast(N,
# 	E), ast(N,H), cfg(N,Q), cfg(O,R), cfg(P,S), cfg(T,O),
# 	cfg(U,P), cfg(V,M), compMemberAccess(N), ast(Q,N), ast(T,
# 	P), ast(T,S), ast(U,W), ast(U,X), ast(V,O), ast(V,Y),
# 	cfg(Q,X), cfg(R,Z), cfg(S,T), cfg(Y,V), ref(A0,U), assignment(T),
# 	assignment(V), ast(Y,Z), ast(W,K), ast(W,T), ast(W,V),
# 	ast(W,B0), ast(Z,R), cfg(Z,Y), alloc(Z), ast(B0,A),
# 	ast(B0,I), ast(B0,J), ast(B0,Q).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [7 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A), ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,I), cfg(E,B), cfg(G,C), ref(D,J), compMemberAccess(B), compMemberAccess(C), ast(I,D), cfg(F,E), cfg(H,G), cfg(I,K), cfg(L,H), ref(E,J), ref(F,M), ref(G,J), ref(H,N), ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,Q), cfg(O,R), cfg(P,L), cfg(S,O), cfg(T,K), ref(Q,N), ref(U,M), ref(V,N), ref(W,N), ast(S,U), ast(T,O), ast(T,R), cfg(Q,X), cfg(R,T), cfg(U,S), cfg(V,Y), cfg(W,Z), cfg(A0,U), cfg(B0,V), cfg(C0,W), assignment(S), assignment(T), ast(A0,V), ast(A0,D0), ast(B0,W), ast(B0,Z), ast(C0,E0), ast(C0,F0), cfg(X,G0), cfg(Y,H0), cfg(Z,B0), cfg(D0,A0), ref(I0,C0), assignment(A0), assignment(B0), ast(E0,N), ast(E0,A0), ast(E0,B0), ast(E0,J0), ast(D0,H0), ast(D0,K0), ast(H0,Y), ast(G0,Q), ast(G0,X), cfg(H0,D0), cfg(G0,L0), cfg(L0,F0), compMemberAccess(G0), alloc(H0), ast(J0,J), ast(J0,M), ast(J0,S), ast(J0,L0), ast(J0,M0), ast(L0,G0), ast(M0,I), ast(M0,L), ast(M0,T), ast(M0,N0), ast(N0,A).
# [Most-specific clause reduced by 1 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A),
# 	ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,
# 	I), cfg(E,B), cfg(G,C), ref(D,J), compMemberAccess(B),
# 	compMemberAccess(C), ast(I,D), cfg(F,E), cfg(H,G), cfg(I,
# 	K), cfg(L,H), ref(E,J), ref(F,M), ref(G,J), ref(H,N),
# 	ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,
# 	Q), cfg(O,R), cfg(P,L), cfg(S,O), cfg(T,K), ref(Q,N),
# 	ref(U,M), ref(V,N), ref(W,N), ast(S,U), ast(T,O), ast(T,
# 	R), cfg(Q,X), cfg(R,T), cfg(U,S), cfg(V,Y), cfg(W,Z),
# 	cfg(A0,U), cfg(B0,V), cfg(C0,W), assignment(S), assignment(T),
# 	ast(A0,V), ast(A0,D0), ast(B0,W), ast(B0,Z), ast(C0,
# 	E0), ast(C0,F0), cfg(X,G0), cfg(Y,H0), cfg(Z,B0), cfg(D0,
# 	A0), ref(I0,C0), assignment(A0), assignment(B0), ast(E0,
# 	N), ast(E0,A0), ast(E0,B0), ast(E0,J0), ast(D0,H0), ast(H0,
# 	Y), ast(G0,Q), ast(G0,X), cfg(H0,D0), cfg(G0,K0), cfg(K0,
# 	F0), compMemberAccess(G0), alloc(H0), ast(J0,J), ast(J0,
# 	M), ast(J0,S), ast(J0,K0), ast(J0,L0), ast(K0,G0), ast(L0,
# 	I), ast(L0,L), ast(L0,T), ast(L0,M0), ast(M0,A).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(A,B).]
# [C:8,20,10,0 bug(A) :- cfg(B,A).]
# [5 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
#
# [Total time taken 3.480s]

# %%
rule = "bug(A) :- ast(A,B), ast(A,C), cfg(A,D), cfg(B,A), assignment(A), ast(B,E), ast(B,F), ast(C,G), ast(C,H), cfg(C,F), cfg(D,I), cfg(E,B), cfg(G,C), ref(D,J), compMemberAccess(B), compMemberAccess(C), ast(I,D), cfg(F,E), cfg(H,G), cfg(I,K), cfg(L,H), ref(E,J), ref(F,M), ref(G,J), ref(H,N), ref(K,J), ref(O,J), ast(L,K), ast(L,P), cfg(K,P), cfg(L,Q), cfg(O,R), cfg(P,L), cfg(S,O), cfg(T,K), ref(Q,N), ref(U,M), ref(V,N), ref(W,N), ast(S,U), ast(T,O), ast(T,R), cfg(R,T), cfg(Q,X), cfg(U,S), cfg(V,Y), cfg(W,Z), cfg(A0,W), cfg(B0,U), cfg(C0,V), assignment(S), assignment(T), ast(A0,D0), ast(A0,E0), ast(B0,V), ast(B0,F0), ast(C0,W), ast(C0,Z), cfg(Z,C0), cfg(Y,G0), cfg(X,H0), cfg(F0,B0), ref(I0,A0), assignment(B0), assignment(C0), ast(F0,G0), ast(D0,N), ast(D0,B0), ast(D0,C0), ast(D0,J0), ast(H0,Q), ast(H0,X), ast(G0,Y), cfg(H0,K0), cfg(G0,F0), cfg(K0,E0), compMemberAccess(H0), alloc(G0), ast(J0,J), ast(J0,M), ast(J0,S), ast(J0,K0), ast(J0,L0), ast(K0,H0), ast(L0,I), ast(L0,L), ast(L0,T), ast(L0,M0), ast(M0,A)."
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %% [markdown]
# ## High-level Rules
#
# As we add more examples, Progol is able to learn more complex rules. However, the long rules can become noisy, and make it much harder to find rules which apply generally. In this section we try to add a bunch of rules which give Progol the opportunity to compress its rules into smaller, normalised forms.
#
# ### `runs_before`
# First, we add the `runs_before` relation, which should compress and normalise many CFG relations. For example, if ILP had found the following two rules:
#
#   1. `bug(A) :- writeToPointer(A), cfg(A,B), cfg(B,C), cfg(C,D), alloc(D).`
#   2. `bug(A) :- writeToPointer(A), cfg(A,B), alloc(B).`
#
# It may not be able to reconcile them. But, we (the humans) know that it doesn't really matter that there were three cfg edges instead of one, we only care that the allocation happened before the `writeToPointer`.

# %%
header = """
% Settings
:- set(c,10)?
:- set(i,10)?
:- set(h,1000)?
:- set(cover)?
:- set(inflate,200)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

:- modeb(10, runs_before(+node, -node))?

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).
"""

script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})
with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,10)? - Time taken 0.00s]
# [:- set(i,10)? - Time taken 0.00s]
# [:- set(h,1000)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,200)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(10,runs_before(+node,-node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), runs_before(A,I), runs_before(A,J), ast(B,K), ast(B,L), ast(F,G), ast(H,I), ast(I,J), ast(I,M), ref(C,N), ref(D,O), ref(G,O), compMemberAccess(I), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,I), runs_before(B,J), runs_before(B,M), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,J), runs_before(C,K), runs_before(C,M), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,M), runs_before(G,E), runs_before(H,E), runs_before(H,F), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), ast(K,P), ref(M,O), ref(Q,N), ref(R,O), ref(S,O), ref(T,O), sizeOf(K), runs_before(K,A), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(K,H), runs_before(K,I), runs_before(K,J), runs_before(K,M), runs_before(L,A), runs_before(L,B), runs_before(L,E), runs_before(L,F), runs_before(L,G), runs_before(L,H), runs_before(L,I), runs_before(L,J), runs_before(L,K), runs_before(L,M), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,H), runs_before(M,I), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,M), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,M), runs_before(R,A), runs_before(R,B), runs_before(R,E), runs_before(R,F), runs_before(R,G), runs_before(R,H), runs_before(R,I), runs_before(R,J), runs_before(R,K), runs_before(R,M), runs_before(S,A), runs_before(S,B), runs_before(S,E), runs_before(S,F), runs_before(S,G), runs_before(S,H), runs_before(S,I), runs_before(S,J), runs_before(S,K), runs_before(S,M), runs_before(T,A), runs_before(T,B), runs_before(T,E), runs_before(T,F), runs_before(T,G), runs_before(T,H), runs_before(T,I), runs_before(T,J), runs_before(T,K), runs_before(T,M).
# [Most-specific clause reduced by 56 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), runs_before(A,H), runs_before(A,I), ast(B,J), ast(B,
# 	K), ast(E,F), ast(G,H), ast(H,I), ast(H,L), ref(C,M),
# 	ref(F,M), compMemberAccess(H), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	H), runs_before(B,I), runs_before(B,L), runs_before(C,
# 	A), runs_before(C,B), runs_before(C,D), runs_before(C,
# 	E), runs_before(C,F), runs_before(C,G), runs_before(C,
# 	H), runs_before(C,I), runs_before(C,J), runs_before(C,
# 	L), runs_before(F,D), runs_before(G,D), runs_before(G,
# 	E), runs_before(H,D), runs_before(H,E), runs_before(H,
# 	F), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), ast(J,N), ref(L,M), sizeOf(J),
# 	runs_before(J,A), runs_before(J,D), runs_before(J,E),
# 	runs_before(J,F), runs_before(J,G), runs_before(J,H),
# 	runs_before(J,I), runs_before(J,L), runs_before(K,A),
# 	runs_before(K,B), runs_before(K,D), runs_before(K,E),
# 	runs_before(K,F), runs_before(K,G), runs_before(K,H),
# 	runs_before(K,I), runs_before(K,J), runs_before(K,L),
# 	runs_before(L,D), runs_before(L,E), runs_before(L,F),
# 	runs_before(L,G), runs_before(L,H), runs_before(N,A),
# 	runs_before(N,B), runs_before(N,D), runs_before(N,E),
# 	runs_before(N,F), runs_before(N,G), runs_before(N,H),
# 	runs_before(N,I), runs_before(N,L).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [10 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), runs_before(A,I), runs_before(A,J), ast(B,K), ast(B,L), ast(F,G), ast(H,I), ast(I,J), ast(I,M), ref(C,N), ref(D,O), ref(G,O), compMemberAccess(I), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,I), runs_before(B,J), runs_before(B,M), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,J), runs_before(C,K), runs_before(C,M), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,M), runs_before(G,E), runs_before(H,E), runs_before(H,F), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), ast(K,P), ref(M,O), ref(Q,O), ref(R,O), ref(S,O), ref(T,N), sizeOf(K), runs_before(K,A), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(K,H), runs_before(K,I), runs_before(K,J), runs_before(K,M), runs_before(L,A), runs_before(L,B), runs_before(L,E), runs_before(L,F), runs_before(L,G), runs_before(L,H), runs_before(L,I), runs_before(L,J), runs_before(L,K), runs_before(L,M), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,H), runs_before(M,I), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,M), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,M), runs_before(R,A), runs_before(R,B), runs_before(R,E), runs_before(R,F), runs_before(R,G), runs_before(R,H), runs_before(R,I), runs_before(R,J), runs_before(R,K), runs_before(R,M), runs_before(S,A), runs_before(S,B), runs_before(S,E), runs_before(S,F), runs_before(S,G), runs_before(S,H), runs_before(S,I), runs_before(S,J), runs_before(S,K), runs_before(S,M), runs_before(T,A), runs_before(T,B), runs_before(T,E), runs_before(T,F), runs_before(T,G), runs_before(T,H), runs_before(T,I), runs_before(T,J), runs_before(T,K), runs_before(T,M).
# [Most-specific clause reduced by 56 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), runs_before(A,H), runs_before(A,I), ast(B,J), ast(B,
# 	K), ast(E,F), ast(G,H), ast(H,I), ast(H,L), ref(C,M),
# 	ref(F,M), compMemberAccess(H), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	H), runs_before(B,I), runs_before(B,L), runs_before(C,
# 	A), runs_before(C,B), runs_before(C,D), runs_before(C,
# 	E), runs_before(C,F), runs_before(C,G), runs_before(C,
# 	H), runs_before(C,I), runs_before(C,J), runs_before(C,
# 	L), runs_before(F,D), runs_before(G,D), runs_before(G,
# 	E), runs_before(H,D), runs_before(H,E), runs_before(H,
# 	F), runs_before(I,D), runs_before(I,E), runs_before(I,
# 	F), runs_before(I,G), ast(J,N), ref(L,M), sizeOf(J),
# 	runs_before(J,A), runs_before(J,D), runs_before(J,E),
# 	runs_before(J,F), runs_before(J,G), runs_before(J,H),
# 	runs_before(J,I), runs_before(J,L), runs_before(K,A),
# 	runs_before(K,B), runs_before(K,D), runs_before(K,E),
# 	runs_before(K,F), runs_before(K,G), runs_before(K,H),
# 	runs_before(K,I), runs_before(K,J), runs_before(K,L),
# 	runs_before(L,D), runs_before(L,E), runs_before(L,F),
# 	runs_before(L,G), runs_before(L,H), runs_before(N,A),
# 	runs_before(N,B), runs_before(N,D), runs_before(N,E),
# 	runs_before(N,F), runs_before(N,G), runs_before(N,H),
# 	runs_before(N,I), runs_before(N,L).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [10 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,J), runs_before(C,H), runs_before(C,
# 	I), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(J,D), runs_before(J,E), runs_before(J,F),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,J), runs_before(I,H), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,M), ref(P,M), ref(Q,L), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,H), runs_before(C,I), runs_before(C,
# 	J), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,H), runs_before(I,J), runs_before(J,D),
# 	runs_before(J,E), runs_before(J,F), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,M), ref(P,M), ref(Q,L), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,J), runs_before(C,H), runs_before(C,
# 	I), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(J,D), runs_before(J,E), runs_before(J,F),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,J), runs_before(I,H), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,M), ref(P,M), ref(Q,L), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,J), runs_before(C,H), runs_before(C,
# 	I), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(J,D), runs_before(J,E), runs_before(J,F),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,J), runs_before(I,H), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,K), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,K), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,I), runs_before(J,K), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,K), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,K), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,K), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,H), runs_before(C,I), runs_before(C,
# 	J), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,H), runs_before(I,J), runs_before(J,D),
# 	runs_before(J,E), runs_before(J,F), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,J), runs_before(C,H), runs_before(C,
# 	I), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(J,D), runs_before(J,E), runs_before(J,F),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,J), runs_before(I,H), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), ast(B,I), ast(B,J), ast(F,G), ast(G,H), ast(G,K), ref(C,L), ref(D,M), compMemberAccess(G), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,K), runs_before(C,A), runs_before(C,B), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,K), runs_before(C,I), runs_before(C,N), runs_before(D,A), runs_before(D,B), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,K), runs_before(D,I), runs_before(D,J), runs_before(D,N), runs_before(G,E), runs_before(H,E), runs_before(H,F), ast(I,N), ref(K,M), ref(O,L), ref(P,M), ref(Q,M), sizeOf(I), runs_before(K,E), runs_before(K,F), runs_before(K,G), runs_before(I,A), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,H), runs_before(I,K), runs_before(J,A), runs_before(J,B), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), runs_before(J,K), runs_before(J,I), runs_before(N,A), runs_before(N,B), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,K), runs_before(O,A), runs_before(O,B), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,K), runs_before(O,I), runs_before(O,J), runs_before(O,N), runs_before(P,A), runs_before(P,B), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,K), runs_before(P,I), runs_before(P,J), runs_before(P,N), runs_before(Q,A), runs_before(Q,B), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,K), runs_before(Q,I), runs_before(Q,J), runs_before(Q,N).
# [Most-specific clause reduced by 44 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), runs_before(A,
# 	D), runs_before(A,E), runs_before(A,F), runs_before(A,
# 	G), ast(B,H), ast(B,I), ast(E,F), ast(F,G), ast(F,J),
# 	ref(C,K), compMemberAccess(F), runs_before(B,D), runs_before(B,
# 	E), runs_before(B,F), runs_before(B,G), runs_before(B,
# 	J), runs_before(C,A), runs_before(C,B), runs_before(C,
# 	D), runs_before(C,E), runs_before(C,F), runs_before(C,
# 	G), runs_before(C,J), runs_before(C,H), runs_before(C,
# 	I), runs_before(C,L), runs_before(F,D), runs_before(G,
# 	D), runs_before(G,E), ast(H,L), ref(J,K), sizeOf(H),
# 	runs_before(J,D), runs_before(J,E), runs_before(J,F),
# 	runs_before(H,A), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,F), runs_before(H,G), runs_before(H,J),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,D),
# 	runs_before(I,E), runs_before(I,F), runs_before(I,G),
# 	runs_before(I,J), runs_before(I,H), runs_before(L,A),
# 	runs_before(L,B), runs_before(L,D), runs_before(L,E),
# 	runs_before(L,F), runs_before(L,G), runs_before(L,J).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,18,9,0 bug(A) :- writeToPointer(A).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [8 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), runs_before(A,D), runs_before(A,E), runs_before(A,F), ast(B,G), ast(B,H), ast(C,I), ast(C,J), ast(E,F), ast(F,K), ast(F,L), compMemberAccess(B), compMemberAccess(C), compMemberAccess(F), runs_before(B,D), runs_before(B,E), runs_before(B,F), runs_before(C,D), runs_before(C,E), runs_before(C,F), runs_before(F,D), ref(L,M), ref(G,N), ref(H,O), ref(I,N), ref(J,M), runs_before(K,D), runs_before(K,E), runs_before(L,D), runs_before(L,E), runs_before(L,F), runs_before(G,D), runs_before(G,E), runs_before(G,F), runs_before(H,D), runs_before(H,E), runs_before(H,F), runs_before(I,D), runs_before(I,E), runs_before(I,F), runs_before(J,D), runs_before(J,E), runs_before(J,F), ref(P,O), ref(Q,N), ref(R,N), ref(S,N), ref(T,M), ref(U,M), runs_before(P,D), runs_before(P,E), runs_before(P,F), runs_before(Q,D), runs_before(Q,E), runs_before(Q,F), runs_before(R,D), runs_before(R,E), runs_before(R,F), runs_before(S,D), runs_before(S,E), runs_before(S,F), runs_before(T,D), runs_before(T,E), runs_before(T,F), runs_before(U,D), runs_before(U,E), runs_before(U,F).
# [Most-specific clause reduced by 47 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), runs_before(A,C), runs_before(A,
# 	D), runs_before(A,E), ast(B,F), ast(D,E), ast(E,G), compMemberAccess(B),
# 	compMemberAccess(E), runs_before(B,C), runs_before(B,
# 	D), runs_before(B,E), runs_before(E,C), ref(G,H), ref(F,
# 	H), runs_before(G,C), runs_before(G,D), runs_before(G,
# 	E), runs_before(F,C), runs_before(F,D), runs_before(F,
# 	E).
#
# [C:9,20,10,0 bug(A).]
# [C:8,20,10,0 bug(A) :- ast(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [C:8,20,10,0 bug(A) :- runs_before(A,B).]
# [5 explored search nodes]
# f=9,p=20,n=10,h=0
# [No compression]
#
#
# [Total time taken 19.770s]

# %%
rule = "bug(A) :- ast(A,B), assignment(A), runs_before(A,C), runs_before(A,D), runs_before(A,E), ast(B,F), ast(D,E), ast(E,G), compMemberAccess(B), compMemberAccess(E), runs_before(B,C), runs_before(B,D), runs_before(B,E), runs_before(E,C), ref(F,H), ref(G,H), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(G,C), runs_before(G,D), runs_before(G,E)."
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %% [markdown]
# ### `ancestor`
#
# Next, we add an equivelant for the `ast` relation, `ancestor`:

# %%
header = """
% Settings
:- set(c,5)?
:- set(i,4)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
:- modeb(*, sizeOf(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

:- modeb(20, runs_before(+node, -node))?

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).

:- modeb(20, ancestor(+node, -node))?

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).
"""

script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})
with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,5)? - Time taken 0.00s]
# [:- set(i,4)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(20,runs_before(+node,-node))? - Time taken 0.00s]
# [:- modeb(20,ancestor(+node,-node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), ancestor(A,H), ancestor(A,I), ancestor(A,J), ref(D,K), compMemberAccess(F), sizeOf(I), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,F), runs_before(H,G), runs_before(H,L), runs_before(H,M), runs_before(I,A), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,L), runs_before(J,A), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,I), runs_before(J,L), runs_before(J,M), ancestor(E,G), ancestor(E,L), ref(L,K), ref(N,K), ref(O,K), ref(P,K), ref(Q,K), runs_before(L,B), runs_before(L,C), runs_before(L,D), runs_before(L,E), runs_before(L,F), runs_before(M,B), runs_before(M,C), runs_before(M,D), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,L), ancestor(M,H), runs_before(N,A), runs_before(N,B), runs_before(N,C), runs_before(N,D), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,I), runs_before(N,J), runs_before(N,L), runs_before(N,M), runs_before(O,A), runs_before(O,B), runs_before(O,C), runs_before(O,D), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,L), runs_before(O,M), runs_before(O,N), runs_before(O,R), runs_before(P,A), runs_before(P,B), runs_before(P,C), runs_before(P,D), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,L), runs_before(P,M), runs_before(P,N), runs_before(P,R), runs_before(Q,A), runs_before(Q,B), runs_before(Q,C), runs_before(Q,D), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,L), runs_before(Q,M), runs_before(Q,N), runs_before(Q,R).
# [Most-specific clause reduced by 42 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), runs_before(A,
# 	F), ancestor(A,G), ancestor(A,H), ancestor(A,I), ref(C,
# 	J), compMemberAccess(E), sizeOf(H), runs_before(C,B),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,B), runs_before(F,C), runs_before(F,D),
# 	runs_before(G,A), runs_before(G,B), runs_before(G,C),
# 	runs_before(G,D), runs_before(G,E), runs_before(G,F),
# 	runs_before(G,K), runs_before(G,L), runs_before(H,A),
# 	runs_before(H,B), runs_before(H,C), runs_before(H,D),
# 	runs_before(H,E), runs_before(H,F), runs_before(H,K),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,C),
# 	runs_before(I,D), runs_before(I,E), runs_before(I,F),
# 	runs_before(I,H), runs_before(I,K), runs_before(I,L),
# 	ancestor(D,F), ancestor(D,K), ref(K,J), ref(M,J), ref(N,
# 	J), runs_before(K,B), runs_before(K,C), runs_before(K,
# 	D), runs_before(K,E), runs_before(L,B), runs_before(L,
# 	C), runs_before(L,D), runs_before(L,E), runs_before(L,
# 	F), runs_before(L,K), ancestor(L,G), runs_before(M,A),
# 	runs_before(M,B), runs_before(M,C), runs_before(M,D),
# 	runs_before(M,E), runs_before(M,F), runs_before(M,G),
# 	runs_before(M,H), runs_before(M,I), runs_before(M,K),
# 	runs_before(M,L), runs_before(N,A), runs_before(N,B),
# 	runs_before(N,C), runs_before(N,D), runs_before(N,E),
# 	runs_before(N,F), runs_before(N,G), runs_before(N,H),
# 	runs_before(N,I), runs_before(N,K), runs_before(N,L),
# 	runs_before(N,M).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [10 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), ancestor(A,H), ancestor(A,I), ancestor(A,J), ref(D,K), compMemberAccess(F), sizeOf(I), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,F), runs_before(H,G), runs_before(H,L), runs_before(H,M), runs_before(I,A), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(I,L), runs_before(J,A), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,I), runs_before(J,L), runs_before(J,M), ancestor(E,G), ancestor(E,L), ref(L,K), ref(N,K), ref(O,K), ref(P,K), ref(Q,K), runs_before(L,B), runs_before(L,C), runs_before(L,D), runs_before(L,E), runs_before(L,F), runs_before(M,B), runs_before(M,C), runs_before(M,D), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,L), ancestor(M,H), runs_before(N,A), runs_before(N,B), runs_before(N,C), runs_before(N,D), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,I), runs_before(N,J), runs_before(N,L), runs_before(N,M), runs_before(O,A), runs_before(O,B), runs_before(O,C), runs_before(O,D), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,L), runs_before(O,M), runs_before(O,N), runs_before(O,R), runs_before(P,A), runs_before(P,B), runs_before(P,C), runs_before(P,D), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,L), runs_before(P,M), runs_before(P,N), runs_before(P,R), runs_before(Q,A), runs_before(Q,B), runs_before(Q,C), runs_before(Q,D), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,L), runs_before(Q,M), runs_before(Q,N), runs_before(Q,R).
# [Most-specific clause reduced by 42 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), runs_before(A,
# 	F), ancestor(A,G), ancestor(A,H), ancestor(A,I), ref(C,
# 	J), compMemberAccess(E), sizeOf(H), runs_before(C,B),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,B), runs_before(F,C), runs_before(F,D),
# 	runs_before(G,A), runs_before(G,B), runs_before(G,C),
# 	runs_before(G,D), runs_before(G,E), runs_before(G,F),
# 	runs_before(G,K), runs_before(G,L), runs_before(H,A),
# 	runs_before(H,B), runs_before(H,C), runs_before(H,D),
# 	runs_before(H,E), runs_before(H,F), runs_before(H,K),
# 	runs_before(I,A), runs_before(I,B), runs_before(I,C),
# 	runs_before(I,D), runs_before(I,E), runs_before(I,F),
# 	runs_before(I,H), runs_before(I,K), runs_before(I,L),
# 	ancestor(D,F), ancestor(D,K), ref(K,J), ref(M,J), ref(N,
# 	J), runs_before(K,B), runs_before(K,C), runs_before(K,
# 	D), runs_before(K,E), runs_before(L,B), runs_before(L,
# 	C), runs_before(L,D), runs_before(L,E), runs_before(L,
# 	F), runs_before(L,K), ancestor(L,G), runs_before(M,A),
# 	runs_before(M,B), runs_before(M,C), runs_before(M,D),
# 	runs_before(M,E), runs_before(M,F), runs_before(M,G),
# 	runs_before(M,H), runs_before(M,I), runs_before(M,K),
# 	runs_before(M,L), runs_before(N,A), runs_before(N,B),
# 	runs_before(N,C), runs_before(N,D), runs_before(N,E),
# 	runs_before(N,F), runs_before(N,G), runs_before(N,H),
# 	runs_before(N,I), runs_before(N,K), runs_before(N,L),
# 	runs_before(N,M).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [10 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), runs_before(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(F,A), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(F,E), runs_before(F,I), runs_before(F,J), runs_before(G,A), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(G,E), runs_before(G,I), runs_before(H,A), runs_before(H,B), runs_before(H,C), runs_before(H,D), runs_before(H,E), runs_before(H,G), runs_before(H,I), runs_before(H,J), ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,B), runs_before(I,C), runs_before(I,D), runs_before(J,B), runs_before(J,C), runs_before(J,D), runs_before(J,E), runs_before(J,I), ancestor(J,F), ref(L,K), ref(M,K), ref(N,K).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), runs_before(A,B), runs_before(A,
# 	C), runs_before(A,D), runs_before(A,E), ancestor(A,F),
# 	ancestor(A,G), ancestor(A,H), compMemberAccess(D), sizeOf(G),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(F,A), runs_before(F,B), runs_before(F,C),
# 	runs_before(F,D), runs_before(F,E), runs_before(F,I),
# 	runs_before(F,J), runs_before(G,A), runs_before(G,B),
# 	runs_before(G,C), runs_before(G,D), runs_before(G,E),
# 	runs_before(G,I), runs_before(H,A), runs_before(H,B),
# 	runs_before(H,C), runs_before(H,D), runs_before(H,E),
# 	runs_before(H,G), runs_before(H,I), runs_before(H,J),
# 	ancestor(C,E), ancestor(C,I), ref(I,K), runs_before(I,
# 	B), runs_before(I,C), runs_before(I,D), runs_before(J,
# 	B), runs_before(J,C), runs_before(J,D), runs_before(J,
# 	E), runs_before(J,I), ancestor(J,F).
#
# [C:39,50,10,0 bug(A).]
# [C:38,45,9,0 bug(A) :- writeToPointer(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [9 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- assignment(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), ancestor(A,E), ancestor(A,F), ancestor(A,G), ancestor(A,H), ref(E,I), ref(F,J), ref(G,I), ref(H,K), compMemberAccess(D), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(E,D), runs_before(F,B), runs_before(F,C), runs_before(F,D), runs_before(G,B), runs_before(G,C), runs_before(G,D), runs_before(H,B), runs_before(H,C), runs_before(H,D), ancestor(C,L), ancestor(C,M), ref(M,K), ref(N,J), ref(O,I), ref(P,I), ref(Q,I), ref(R,K), ref(S,K), runs_before(L,B), runs_before(L,C), runs_before(M,B), runs_before(M,C), runs_before(M,D), runs_before(N,B), runs_before(N,C), runs_before(N,D), runs_before(O,B), runs_before(O,C), runs_before(O,D), runs_before(P,B), runs_before(P,C), runs_before(P,D), runs_before(Q,B), runs_before(Q,C), runs_before(Q,D), runs_before(R,B), runs_before(R,C), runs_before(R,D), runs_before(S,B), runs_before(S,C), runs_before(S,D).
# [Most-specific clause reduced by 42 literals]
# [Most specific clause is]
#
# bug(A) :- assignment(A), runs_before(A,B), runs_before(A,C),
# 	runs_before(A,D), ancestor(A,E), ref(E,F), compMemberAccess(D),
# 	runs_before(D,B), runs_before(E,B), runs_before(E,C),
# 	runs_before(E,D), ancestor(C,G), ref(G,F), runs_before(G,
# 	B), runs_before(G,C), runs_before(G,D).
#
# [C:39,50,10,0 bug(A).]
# [C:20,5,1,0 bug(A) :- assignment(A).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- runs_before(A,B).]
# [C:38,50,10,0 bug(A) :- ancestor(A,B).]
# [6 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
#
# [Total time taken 19.120s]

# %%
rule = "bug(A) :- assignment(A), runs_before(A,B), runs_before(A,C), runs_before(A,D), ancestor(A,E), ref(E,F), compMemberAccess(D), runs_before(D,B), runs_before(E,B), runs_before(E,C), runs_before(E,D), ancestor(C,G), ref(G,F), runs_before(G,B), runs_before(G,C), runs_before(G,D)."
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %% [markdown]
# Rule above shows the system has found related edges, but hasn't found the need to constrain them as much as a human would deem necessary. E.g. there has to be something about B and F that relates them to the bug more than just being references. Potential causes of this issue:
#
#   1. We haven't given the system enough information about the C, B, F nodes for it to extract defining features of them.
#   2. We haven't given it a high enough variety of inputs for the rule to need these extra distinguishing features.
#
# It's probably a combination of the two.

# %% [markdown]
# ### `writeToPointer`
#
# In

# %%
header = """
% Settings
:- set(c,30)?
:- set(i,30)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

writeToPointer(A) :- ast(A, B), assignment(A), compMemberAccess(B). 
"""

script = make_progol_script(header, {
    62804,
    62852,
    62853,
    62854,
    62869,
    62900,
    62901,
    62917,
    232012,
    232086,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,G), sizeOf(E).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_120_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_120_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_127_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_121_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), sizeOf(E).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F), sizeOf(D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), ref(D,H), ref(E,I), ref(F,H), ref(G,J), ref(K,I), ref(L,H), ref(M,H), ref(N,H), ref(O,J), ref(P,J), ref(Q,J).
# [Most-specific clause reduced by 14 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), writeToPointer(A), ast(B,C), ref(C,D).
#
# [C:39,50,10,0 bug(A).]
# [C:38,50,10,0 bug(A) :- ast(A,B).]
# [C:38,50,10,0 bug(A) :- writeToPointer(A).]
# [3 explored search nodes]
# f=39,p=50,n=10,h=0
# [No compression]
#
#
# [Total time taken 0.070s]

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,E), ast(D,F), sizeOf(D)."
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- ast(A,B), writeToPointer(A), ast(B,C), ref(C,D)."
))

# %% [markdown]
# ### `ancestor` and `writeToPointer`

# %%
header = """
% Settings
:- set(c,30)?
:- set(i,30)?
:- set(h,500)?
:- set(inflate,500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?
:- modeb(5, ancestor(+node, -node))?
:- modeb(5, ancestor(-node, +node))?
%:- modeb(*, ast(+node, -node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).

writeToPointer(A) :- ast(A, B), assignment(A), compMemberAccess(B). 

"""

script = make_progol_script(header, {
    62852,
    62900,
    62869,
    62804,
    232012,
    62853,
    62917,
    232086,
    62901,
    62854,
    62867,
    62902,
    62915,
    62868,
    62861,
    62916,
    62909,
    62865,
    62913,
    62821,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(5,ancestor(+node,-node))? - Time taken 0.00s]
# [:- modeb(5,ancestor(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,pointer(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOfInt(+node))? - Time taken 0.00s]
# [:- modeb(100,array10(+node))? - Time taken 0.00s]
# [:- modeb(100,voidPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# ^C

# %% [markdown]
# Below are from 10 examples and no method features:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ast(A,D), ast(A,E), ref(E,F), sizeOf(C), ancestor(D,B), ast(C,B), ast(D,C)."
))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- writeToPointer(A), ancestor(A,B), ast(A,C), ref(B,D), ast(C,B)."
))

# %% [markdown]
# Below is from 20 examples and includes method features:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        """
        bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ast(A,
	D), ast(A,E), ast(A,F), ref(E,G), ref(F,H), sizeOf(C),
	ancestor(D,B), ast(C,B), ast(D,C), pointer(F), sizeOfInt(E),
	array10(E), pointer(H), sizeOfInt(G), array10(G).
        """))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot("""bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
	D), ancestor(A,E), ast(A,F), ast(A,G), ref(B,H), ref(C,
	I), ref(D,H), ref(E,J), ast(F,B), ast(F,C), ast(G,D),
	ast(G,E), pointer(E), sizeOfInt(B), sizeOfInt(C), sizeOfInt(D),
	array10(C), pointer(J), sizeOfInt(I), sizeOfInt(H), 
	array10(I)."""))

# %% [markdown]
# ## *TODO* Tagging the whole tree
#
# Tag buggy trees as a whole instead of one particular node.
#     - Add a tree membership property to each node.
#     - Add tree_id as extra parameter.

# %%
node_and_tree = []
for node in nodes:
    start, end = node.split('_id')
    node_and_tree.append('(' +start+ ', ' +node+ ')')

node_and_tree[0:5]
# Out:
# ['(good_62868, good_62868_id_135_f_memcpy_17_c_l_35_c_21_)',
#  '(bad_62909, bad_62909_id_59_f_l_c_)',
#  '(good_232086, good_232086_id_134_f_memmove_01_c_l_34_c_13_)',
#  '(bad_62852, bad_62852_id_123_f_memcpy_01_c_l_27_c_12_)',
#  '(good_62804, good_62804_id_167_f_l_23_c_0_)']

# %%
node_tree_types = [
    'node'+ node_tree +'.' for node_tree in node_and_tree
]

tree_positive_examples = [
    'bug('+node_id+').' for node_id in bad_node
]

tree_negative_examples = [
    ':- bug('+node_id+').' for node_id in good_node
]

# %%
def extract_tree_ids(tree):
    line = tree.split('\n')[2]
    line = line.strip()
    line = line.split('(')[1]
    tree_id = line.split('_id')[0]

    return tree_id

# %%
tree_ids = []
for tree in prolog.tree:
    tree_ids.append(extract_tree_ids(tree))

# %%
trees = [
    'tree('+ tree_label +').' for tree_label in tree_ids
]

# %%
def make_progol_script_tag_whole_tree(header, testcases):
    script_template = """
{header}

# %%Trees
{trees}

%% Types
{types}

%% background knowledge
{bg_knowledge}

%% learning task
%% positive examples
{positive_examples}

%% negative examples
{negative_examples}

    """
    script = script_template.format(
        header = header,
        trees =  '\n'.join(trees),
        types = '\n'.join(node_tree_types),
        bg_knowledge = '\n'.join(prolog['tree']),
        positive_examples='\n'.join(tree_positive_examples),
        negative_examples='\n'.join(tree_negative_examples),
    )
    
    # remove all lines not related to this testcase
    script = '\n'.join([
        line for line in script.split("\n")  if any(
            str(testcase) in line for testcase in testcases
        ) or not ("good_" in line or "bad_" in line)
    ])
    
    return script

# %%
header = """
% Settings
:- set(c,30)?
:- set(i,30)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ast(+node,-node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, assignment(+node))?
:- modeb(*, compMemberAccess(+node))?
% :- modeb(*, sizeOf(+node))?
:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

"""

script = make_progol_script_tag_whole_tree(header, {62804, 62852, 62869, 232012, 62900})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,30)? - Time taken 0.00s]
# [:- set(i,30)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,assignment(+node))? - Time taken 0.00s]
# [:- modeb(100,compMemberAccess(+node))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_146_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H), ref(N,H), ref(O,H).
# [Most-specific clause reduced by 9 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_121_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,G), ref(K,H), ref(L,H), ref(M,H).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- ast(A,B), ast(A,C), ast(A,D), writeToPointer(A), ast(B,E), ast(B,F), ref(C,G), ref(D,H), ast(E,I), ref(J,H), ref(K,H), ref(L,H), ref(M,G).
# [Most-specific clause reduced by 7 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
# 	E), ast(D,F).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:18,20,4,0 bug(A) :- writeToPointer(A).]
# [4 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- ast(A,B), ast(A,C), assignment(A), ast(B,D), ast(B,E), ast(C,F), ast(C,G), compMemberAccess(B), compMemberAccess(C), ref(D,H), ref(E,I), ref(F,H), ref(G,J), ref(K,I), ref(L,J), ref(M,J), ref(N,J), ref(O,H), ref(P,H), ref(Q,H).
# [Most-specific clause reduced by 15 literals]
# [Most specific clause is]
#
# bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B),
# 	ref(C,D).
#
# [C:19,25,5,0 bug(A).]
# [C:18,25,5,0 bug(A) :- ast(A,B).]
# [C:10,5,1,0 bug(A) :- assignment(A).]
# [3 explored search nodes]
# f=19,p=25,n=5,h=0
# [No compression]
#
#
# [Total time taken 0.012s]

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot("""bug(A) :- ast(A,B), ast(A,C), writeToPointer(A), ast(B,D), ref(C,
	E), ast(D,F)."""))

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot("""bug(A) :- ast(A,B), assignment(A), ast(B,C), compMemberAccess(B),
	ref(C,D)."""))

# %% [markdown]
# ## *TODO* Try detect a simpler bug
#
# Try to detect a simpler bug first: "was there any memory allocated to this pointer in the first place?".

# %% [markdown]
# ## *TODO* Add properties to _positively_ describe the buggy behaviour
#
# First, tell Progol that it is allowed to use the fact that a node _isn't_ a call to `sizeof`:
#
# ```
# :- modeb(*, not(sizeOf(+node)))?
# ```

# %%
header = """
% Settings
:- set(c,10)?
:- set(i,10)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,1500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, sizeOf(+node))?
:- modeb(1, not(sizeOf(+node)))?

:- modeb(*, malloc(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?
:- modeb(10, ancestor(+node, -node))?
:- modeb(10, runs_before(+node, -node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

writeToPointer(A) :- ast(A, B), assignment(A), compMemberAccess(B). 

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).
"""

script = make_progol_script(header, {
    62852,
    62900,
    62869,
    62804,
    232012,
    62853,
    62917,
    232086,
    62901,
    62854,
    62867,
    62902,
    62915,
    62868,
    62861,
    62916,
    62909,
    62865,
    62913,
    62821,
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,10)? - Time taken 0.00s]
# [:- set(i,10)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,1500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(1,not(sizeOf(+node)))? - Time taken 0.00s]
# [:- modeb(100,malloc(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(10,ancestor(+node,-node))? - Time taken 0.00s]
# [:- modeb(10,runs_before(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,pointer(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOfInt(+node))? - Time taken 0.00s]
# [:- modeb(100,array10(+node))? - Time taken 0.00s]
# [:- modeb(100,voidPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- not(sizeOf(A)), writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), runs_before(A,E), runs_before(A,F), runs_before(A,G), runs_before(A,H), runs_before(A,I), runs_before(A,J), not(sizeOf(B)), not(sizeOf(D)), not(sizeOf(E)), not(sizeOf(F)), not(sizeOf(G)), not(sizeOf(H)), not(sizeOf(I)), not(sizeOf(J)), ref(G,K), sizeOf(C), ancestor(H,J), ancestor(H,L), runs_before(B,A), runs_before(B,E), runs_before(B,F), runs_before(B,G), runs_before(B,H), runs_before(B,I), runs_before(B,J), runs_before(B,L), runs_before(B,M), runs_before(C,A), runs_before(C,E), runs_before(C,F), runs_before(C,G), runs_before(C,H), runs_before(C,I), runs_before(C,J), runs_before(C,L), runs_before(D,A), runs_before(D,C), runs_before(D,E), runs_before(D,F), runs_before(D,G), runs_before(D,H), runs_before(D,I), runs_before(D,J), runs_before(D,L), runs_before(D,M), runs_before(G,E), runs_before(H,E), runs_before(H,F), runs_before(I,E), runs_before(I,F), runs_before(I,G), runs_before(J,E), runs_before(J,F), runs_before(J,G), runs_before(J,H), pointer(G), voidPointer(E), not(sizeOf(K)), not(sizeOf(L)), not(sizeOf(M)), ref(L,K), ref(N,K), ref(O,K), ref(P,K), ref(Q,K), ancestor(M,B), runs_before(L,E), runs_before(L,F), runs_before(L,G), runs_before(L,H), runs_before(L,I), runs_before(M,E), runs_before(M,F), runs_before(M,G), runs_before(M,H), runs_before(M,I), runs_before(M,J), runs_before(M,L), pointer(K), pointer(L), not(sizeOf(N)), not(sizeOf(O)), not(sizeOf(P)), not(sizeOf(Q)), runs_before(N,A), runs_before(N,C), runs_before(N,E), runs_before(N,F), runs_before(N,G), runs_before(N,H), runs_before(N,I), runs_before(N,J), runs_before(N,L), runs_before(N,M), runs_before(O,A), runs_before(O,C), runs_before(O,E), runs_before(O,F), runs_before(O,G), runs_before(O,H), runs_before(O,I), runs_before(O,J), runs_before(O,L), runs_before(O,M), runs_before(P,A), runs_before(P,C), runs_before(P,E), runs_before(P,F), runs_before(P,G), runs_before(P,H), runs_before(P,I), runs_before(P,J), runs_before(P,L), runs_before(P,M), runs_before(Q,A), runs_before(Q,C), runs_before(Q,E), runs_before(Q,F), runs_before(Q,G), runs_before(Q,H), runs_before(Q,I), runs_before(Q,J), runs_before(Q,L), runs_before(Q,M), pointer(N), pointer(O), pointer(P), pointer(Q).
# [Most-specific clause reduced by 50 literals]
# [Most specific clause is]
#
# bug(A) :- not(sizeOf(A)), writeToPointer(A), ancestor(A,B), ancestor(A,
# 	C), ancestor(A,D), runs_before(A,E), runs_before(A,F),
# 	runs_before(A,G), runs_before(A,H), runs_before(A,I),
# 	not(sizeOf(B)), not(sizeOf(D)), not(sizeOf(E)), not(sizeOf(F)),
# 	not(sizeOf(G)), not(sizeOf(H)), not(sizeOf(I)), ref(F,
# 	J), sizeOf(C), ancestor(G,I), ancestor(G,K), runs_before(B,
# 	A), runs_before(B,E), runs_before(B,F), runs_before(B,
# 	G), runs_before(B,H), runs_before(B,I), runs_before(B,
# 	K), runs_before(B,L), runs_before(C,A), runs_before(C,
# 	E), runs_before(C,F), runs_before(C,G), runs_before(C,
# 	H), runs_before(C,I), runs_before(C,K), runs_before(D,
# 	A), runs_before(D,C), runs_before(D,E), runs_before(D,
# 	F), runs_before(D,G), runs_before(D,H), runs_before(D,
# 	I), runs_before(D,K), runs_before(D,L), runs_before(F,
# 	E), runs_before(G,E), runs_before(H,E), runs_before(H,
# 	F), runs_before(I,E), runs_before(I,F), runs_before(I,
# 	G), pointer(F), voidPointer(E), not(sizeOf(J)), not(sizeOf(K)),
# 	not(sizeOf(L)), ref(K,J), ref(M,J), ancestor(L,B), runs_before(K,
# 	E), runs_before(K,F), runs_before(K,G), runs_before(K,
# 	H), runs_before(L,E), runs_before(L,F), runs_before(L,
# 	G), runs_before(L,H), runs_before(L,I), runs_before(L,
# 	K), pointer(J), pointer(K), not(sizeOf(M)), runs_before(M,
# 	A), runs_before(M,C), runs_before(M,E), runs_before(M,
# 	F), runs_before(M,G), runs_before(M,H), runs_before(M,
# 	I), runs_before(M,K), runs_before(M,L), pointer(M).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- not(sizeOf(A)).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- runs_before(A,B).]
# [C:278,300,20,0 bug(A) :- runs_before(A,B).]
# [C:278,300,20,0 bug(A) :- runs_before(A,B).]
# [C:278,300,20,0 bug(A) :- runs_before(A,B).]
# [C:278,300,20,0 bug(A) :- runs_before(A,B).]
# [11 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# ^C

# %%
rule = """bug(A) :- not(sizeOf(A)), writeToPointer(A), ancestor(A,B), runs_before(A,
	C), runs_before(A,D), runs_before(A,E), not(sizeOf(B)),
	not(sizeOf(C)), not(sizeOf(D)), not(sizeOf(E)), ref(B,
	F), ancestor(D,G), runs_before(B,C), runs_before(B,D),
	runs_before(B,E), runs_before(E,C), not(sizeOf(F)), 
	not(sizeOf(G)), ref(G,F), runs_before(G,C), runs_before(G,
	D), runs_before(G,E)."""

graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %%
rule = """bug(A) :- not(sizeOf(A)), writeToPointer(A), ancestor(A,B), ancestor(A,
	C), ancestor(A,D), runs_before(A,E), runs_before(A,F),
	runs_before(A,G), runs_before(A,H), not(sizeOf(B)), 
	not(sizeOf(D)), not(sizeOf(E)), not(sizeOf(F)), not(sizeOf(G)),
	not(sizeOf(H)), sizeOf(C), ancestor(F,H), ancestor(F,
	I), runs_before(B,A), runs_before(B,E), runs_before(B,
	F), runs_before(B,G), runs_before(B,H), runs_before(B,
	I), runs_before(B,J), runs_before(C,A), runs_before(C,
	E), runs_before(C,F), runs_before(C,G), runs_before(C,
	H), runs_before(C,I), runs_before(D,A), runs_before(D,
	C), runs_before(D,E), runs_before(D,F), runs_before(D,
	G), runs_before(D,H), runs_before(D,I), runs_before(D,
	J), runs_before(G,E), runs_before(H,E), runs_before(H,
	F), not(sizeOf(I)), not(sizeOf(J)), ref(I,K), ancestor(J,
	B), runs_before(I,E), runs_before(I,F), runs_before(I,
	G), runs_before(J,E), runs_before(J,F), runs_before(J,
	G), runs_before(J,H), runs_before(J,I), not(sizeOf(K)),
	ref(L,K), not(sizeOf(L)), runs_before(L,A), runs_before(L,
	B), runs_before(L,C), runs_before(L,D), runs_before(L,
	E), runs_before(L,F), runs_before(L,G), runs_before(L,
	H), runs_before(L,I), runs_before(L,J)."""

graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %% [markdown]
# Maybe it uses this not a bit too keenly... Can we make tell it to use it only in a specific context? Try this by adding the following background knowledge and mode declaration:
#
# ```
# :- modeb(*, alloc_doesnt_check_sizeOf(+node))?
#
# checks_sizeOf(A) :- ancestor(A, B), sizeof(B).
# alloc_doesnt_check_sizeOf(A) :- alloc(A), not(checks_sizeOf(A)).
# ```

# %% [markdown]
# It ended up just not making use of this :( Why?

# %% [markdown]
# #### Idea?
#
# One problem we seem to have in general is that if we give the system too much flexibility in navigating the graph, the generalisation step becomes computationnally infeasible. So far, most of our results have been from only allowing navigation through the `cfg` nd `ast` edges in _one direction_. This poses a problem for finding a pattern which matches our bug.
#
# For example, in some of the rules above, we often end up with structures like:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(
        "bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ast(A,D), ast(A,E), ref(E,F), sizeOf(C), ancestor(D,B), ast(C,B), ast(D,C)."
))

# %% [markdown]
# But it's possible that the system needs to be able to walk up the tree from `F` to find the distingishing part of the code: the malloc call. I.e. we want the rule to look like a bit like this:

# %%
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot("""
bug(A) :- writeToPointer(A), ancestor(A,C), ancestor(A,E), ref(E,F), sizeOf(C), ancestor(C,B), 
	ancestor(G,F), ancestor(G,H), alloc(H), ancestor(H,I), not(sizeOf(I)).
"""))

# %% [markdown]
# Importantly, the system needs to be free to to generate the `ancestor(G,F)` edge. This requires allowing the following in the rule body:
# ```
# :- modeb(10, ancestor(+node, -node))?
# :- modeb(10, ancestor(-node, +node))?
# ```
#
# However, as soon as you allow the system to walk up and down the tree, the search space increases massively. This idea does run, but it requires us to also set the following limits:
# ```
# :- set(c,3)?
# :- set(i,3)?
# ```
#
# which massively limit Progols ability to search. So it doesn't find the distinguishing features anyway:

# %%
header = """
% Settings
:- set(c,3)?
:- set(i,3)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,1500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, sizeOf(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?
:- modeb(*, alloc_doesnt_check_sizeOf(+node))?
:- modeb(10, ast(+node, -node))?
:- modeb(10, ast(-node, +node))?
%:- modeb(10, runs_before(+node, -node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

writeToPointer(A) :- ast(A, B), assignment(A), compMemberAccess(B). 

checks_sizeOf(A) :- ancestor(A, B), sizeof(B).
alloc_doesnt_check_sizeOf(A) :- alloc(A), not(checks_sizeOf(A)).

% ancestor(A,C) :- ast(A,B), ancestor(B,C).
% ancestor(A,C) :- ast(A,B), ast(B,C).

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).
"""

script = make_progol_script(header, {
    62852, 62900, 62869, 62804, 232012, 62853, 62917, 232086, 62901, 62854, 62867, 62902, 62915, 62868, 62861, 62916, 62909, 62865, 62913, 62821
})

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,3)? - Time taken 0.00s]
# [:- set(i,3)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,1500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc_doesnt_check_sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(10,ast(+node,-node))? - Time taken 0.00s]
# [:- modeb(10,ast(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,pointer(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOfInt(+node))? - Time taken 0.00s]
# [:- modeb(100,array10(+node))? - Time taken 0.00s]
# [:- modeb(100,voidPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(E,L), ast(M,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(N,G), ref(O,G), ref(P,G), ref(Q,G), ref(R,G), ref(S,F), sizeOf(H), ast(J,N), ast(K,T), ast(L,S), ast(H,U), ast(M,G), ast(M,V), ast(M,W), ast(M,X), ast(Y,M), pointer(G), sizeOfInt(F), array10(F), voidPointer(M).
# [Most-specific clause reduced by 16 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(E,L), ast(M,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(N,F), ref(O,G), ref(P,G), ref(Q,G), ref(R,G), ref(S,G), sizeOf(H), ast(H,T), ast(J,O), ast(K,U), ast(L,N), ast(M,G), ast(M,V), ast(M,W), ast(M,X), ast(Y,M), pointer(G), sizeOfInt(F), array10(F), voidPointer(M).
# [Most-specific clause reduced by 16 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_121_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_121_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(J,Q), ast(K,P), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(L,U), ast(L,V), ast(W,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 13 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62916_id_133_f_memmove_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62916_id_133_f_memmove_17_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(H,Q), ast(J,R), ast(K,P), ast(L,G), ast(L,S), ast(L,T), ast(L,U), ast(V,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 12 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62915_id_121_f_memmove_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62915_id_121_f_memmove_16_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(J,Q), ast(K,P), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62913_id_127_f_memmove_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62913_id_127_f_memmove_14_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(H,Q), ast(J,R), ast(K,M), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62909_id_121_f_memmove_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62909_id_121_f_memmove_10_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(H,Q), ast(J,R), ast(K,P), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62902_id_127_f_memmove_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62902_id_127_f_memmove_03_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(H,Q), ast(J,R), ast(K,M), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(J,Q), ast(K,M), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(J,Q), ast(K,M), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(H,Q), ast(J,R), ast(K,P), ast(L,G), ast(L,S), ast(L,T), ast(L,U), ast(L,V), ast(W,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 13 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(H,Q), ast(J,R), ast(K,P), ast(L,G), ast(L,S), ast(L,T), ast(L,U), ast(V,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 12 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(J,Q), ast(K,M), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(J,Q), ast(K,M), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(H,Q), ast(J,R), ast(K,P), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,G), ref(N,G), ref(O,G), ref(P,F), sizeOf(H), ast(J,Q), ast(K,P), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(J,Q), ast(K,M), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,A), ref(C,F), ref(D,G), ast(B,H), ast(B,I), ast(E,F), ast(E,J), ast(E,K), ast(L,E), pointer(D), sizeOfInt(C), array10(C), voidPointer(E), ref(M,F), ref(N,G), ref(O,G), ref(P,G), sizeOf(H), ast(J,Q), ast(K,M), ast(H,R), ast(L,G), ast(L,S), ast(L,T), ast(U,L), pointer(G), sizeOfInt(F), array10(F), voidPointer(L).
# [Most-specific clause reduced by 11 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
# 	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
# 	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
# 	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
# 	sizeOfInt(F), array10(F), voidPointer(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [6 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62821_id_110_f_loop_18_c_l_34_c_12_).]
# [Generalising <bug(bad_62821_id_110_f_loop_18_c_l_34_c_12_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(D,A), ast(B,E), ast(B,F), ast(C,G), ast(C,H), ast(I,D), voidPointer(D), ref(E,J), ref(F,K), ref(G,J), ref(H,L), ast(I,M), ast(I,N), ast(I,O), ast(P,I), pointer(H), sizeOfInt(E), sizeOfInt(F), sizeOfInt(G), array10(F).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(D,A), ast(B,
# 	E), ast(B,F), ast(C,G), ast(C,H), ast(I,D), voidPointer(D),
# 	ref(E,J), ref(F,K), ref(G,J), ref(H,L), ast(M,I), pointer(H),
# 	sizeOfInt(E), sizeOfInt(F), sizeOfInt(G), array10(F).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [5 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(D,A), ast(B,E), ast(B,F), ast(C,G), ast(C,H), ast(I,D), voidPointer(D), ref(E,J), ref(F,K), ref(G,J), ref(H,L), ast(I,M), ast(I,N), ast(I,O), ast(P,I), pointer(H), sizeOfInt(E), sizeOfInt(F), sizeOfInt(G), array10(F).
# [Most-specific clause reduced by 3 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(D,A), ast(B,
# 	E), ast(B,F), ast(C,G), ast(C,H), ast(I,D), voidPointer(D),
# 	ref(E,J), ref(F,K), ref(G,J), ref(H,L), ast(M,I), pointer(H),
# 	sizeOfInt(E), sizeOfInt(F), sizeOfInt(G), array10(F).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(A,B).]
# [C:278,300,20,0 bug(A) :- ast(B,A).]
# [5 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
#
# [Total time taken 89.320s]

# %%
rule = """bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(A,D), ast(E,
	A), ref(C,F), ref(D,G), ast(B,H), ast(E,F), ast(I,E),
	pointer(D), sizeOfInt(C), array10(C), voidPointer(E),
	sizeOf(H), ast(H,J), ast(I,G), ast(K,I), pointer(G),
	sizeOfInt(F), array10(F), voidPointer(I)."""
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %%
rule = """bug(A) :- writeToPointer(A), ast(A,B), ast(A,C), ast(D,A), ast(B,
	E), ast(B,F), ast(C,G), ast(C,H), ast(I,D), voidPointer(D),
	ref(E,J), ref(F,K), ref(G,J), ref(H,L), ast(M,I), pointer(H),
	sizeOfInt(E), sizeOfInt(F), sizeOfInt(G), array10(F)."""
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %% [markdown]
# One potential solve for this is to declare the bug as the root node of each tree (or tagging the tree as a whole as bug, ala the suggestion in the meeting). If you start at the root of the tree, you don't need to allow walking back up it (though we limit the shape of our ast edges to a real tree, so that `A` and `G` would have to share a common `ancestor`).
#
# Lets try this now:

# %%
def find_root_node(tree, nodes):
    """
    Given a <tree_id> e.g. bad_62804 and the list of all node ids, <nodes>, return the root node of the 
    """
    tree_nodes = [node for node in nodes if tree in node]
    
    # root node of each tree seems to be the one with the largest id
    max_id = 0
    root_node = None
    
    for node in tree_nodes:
        node_id = int(node.split("_")[3])
        if node_id >= max_id:
            max_id = node_id
            root_node = node
            
    return root_node

# %%
root_nodes = [find_root_node(tree, nodes) for tree in tree_ids]
root_nodes[0:5]
# Out:
# ['bad_232086_id_185_f_l_c_',
#  'bad_232012_id_185_f_l_c_',
#  'bad_62917_id_151_f_l_c_',
#  'bad_62916_id_174_f_l_c_',
#  'bad_62915_id_153_f_l_c_']

# %%
root_positive_examples = [
    "bug(" + node + ").\n" for node in root_nodes if 'bad' in node
]
root_negative_examples = [
    ":- bug("+ node + ").\n" for node in root_nodes if 'good' in node
]

# %%
header = """
% Settings
:- set(c,4)?
:- set(i,3)?
:- set(h,500)?
:- set(cover)?
:- set(inflate,1500)?

% Mode declarations
:- modeh(*, bug(+node))?

:- modeb(*, ref(+node,-node))?
:- modeb(*, ref(-node,+node))?

:- modeb(*, sizeOf(+node))?
:- modeb(*, alloc(+node))?
:- modeb(*, writeToPointer(+node))?
:- modeb(*, alloc_doesnt_check_sizeOf(+node))?
:- modeb(*, ancestor(+node, -node))?
:- modeb(*, cfg(+node, -node))?
:- modeb(*, cfg(-node, +node))?

:- modeb(*, pointer(+node))?
:- modeb(*, sizeOfInt(+node))?
:- modeb(*, array10(+node))?
:- modeb(*, voidPointer(+node))?

writeToPointer(A) :- ast(A, B), assignment(A), compMemberAccess(B). 

contains_sizeOf_call(A) :- ancestor(A, B), sizeof(B).
alloc_doesnt_check_sizeOf(A) :- alloc(A), not(contains_sizeOf_call(A)).

ancestor(A,C) :- ast(A,B), ancestor(B,C).
ancestor(A,C) :- ast(A,B), ast(B,C).

runs_before(A,C) :- cfg(A,B), runs_before(B,C).
runs_before(A,C) :- cfg(A,B), cfg(B,C).
"""

testcases = {
    62852, 62900, 62869, 62804, 232012, 62853, 62917, 232086, 62901, 62854, 62867, 62902, 62915, 62868, 62861, 62916, 62909, 62865, 62913, 62821
}

script = make_progol_script(
    header, testcases
)

with open("/tmp/progol_input.pl", "w") as f:
    f.write(script)

# !/progol/source/progol /tmp/progol_input.pl
# Out:
# CProgol Version 5.0
#
# [:- set(c,4)? - Time taken 0.00s]
# [:- set(i,3)? - Time taken 0.00s]
# [:- set(h,500)? - Time taken 0.00s]
# [The cover flag has been turned ON]
# [:- set(cover)? - Time taken 0.00s]
# [:- set(inflate,1500)? - Time taken 0.00s]
# [:- modeh(100,bug(+node))? - Time taken 0.00s]
# [:- modeb(100,ref(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,ref(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc(+node))? - Time taken 0.00s]
# [:- modeb(100,writeToPointer(+node))? - Time taken 0.00s]
# [:- modeb(100,alloc_doesnt_check_sizeOf(+node))? - Time taken 0.00s]
# [:- modeb(100,ancestor(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(+node,-node))? - Time taken 0.00s]
# [:- modeb(100,cfg(-node,+node))? - Time taken 0.00s]
# [:- modeb(100,pointer(+node))? - Time taken 0.00s]
# [:- modeb(100,sizeOfInt(+node))? - Time taken 0.00s]
# [:- modeb(100,array10(+node))? - Time taken 0.00s]
# [:- modeb(100,voidPointer(+node))? - Time taken 0.00s]
# [Testing for contradictions]
# [No contradictions found]
# [Generalising bug/1]
# [Generalising bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232086_id_145_f_memmove_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), ref(N,G), ref(O,G), cfg(H,P), cfg(L,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 4 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).]
# [Generalising <bug(bad_232012_id_145_f_memcpy_01_c_l_30_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), ref(N,G), ref(O,G), cfg(H,P), cfg(L,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 4 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62917_id_121_f_memmove_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62917_id_121_f_memmove_18_c_l_31_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62916_id_133_f_memmove_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62916_id_133_f_memmove_17_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62915_id_121_f_memmove_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62915_id_121_f_memmove_16_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62913_id_127_f_memmove_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62913_id_127_f_memmove_14_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62909_id_121_f_memmove_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62909_id_121_f_memmove_10_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62902_id_127_f_memmove_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62902_id_127_f_memmove_03_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62901_id_121_f_memmove_02_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62900_id_121_f_memmove_01_c_l_29_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).]
# [Generalising <bug(bad_62869_id_120_f_memcpy_18_c_l_31_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).]
# [Generalising <bug(bad_62868_id_133_f_memcpy_17_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).]
# [Generalising <bug(bad_62867_id_120_f_memcpy_16_c_l_33_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).]
# [Generalising <bug(bad_62865_id_127_f_memcpy_14_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).]
# [Generalising <bug(bad_62861_id_120_f_memcpy_10_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).]
# [Generalising <bug(bad_62854_id_128_f_memcpy_03_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).]
# [Generalising <bug(bad_62853_id_120_f_memcpy_02_c_l_32_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).]
# [Generalising <bug(bad_62852_id_121_f_memcpy_01_c_l_29_c_8_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D), pointer(E), ref(I,J), ref(K,G), ref(L,G), ref(M,G), cfg(H,N), cfg(K,I), pointer(G), sizeOfInt(I), array10(I).
# [Most-specific clause reduced by 2 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), cfg(A,E), cfg(F,A), ref(E,G), sizeOf(C), ancestor(F,
# 	B), cfg(B,C), cfg(C,F), cfg(D,B), cfg(E,H), cfg(I,D),
# 	pointer(E), ref(I,J), ref(K,G), cfg(H,L), cfg(K,I),
# 	pointer(G), sizeOfInt(I), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [7 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62821_id_110_f_loop_18_c_l_34_c_12_).]
# [Generalising <bug(bad_62821_id_110_f_loop_18_c_l_34_c_12_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), ancestor(A,E), cfg(A,F), cfg(G,A), ref(B,H), ref(C,I), ref(D,H), ref(E,J), ref(F,H), cfg(B,G), cfg(C,B), cfg(D,K), cfg(E,D), cfg(F,L), cfg(K,C), cfg(M,E), pointer(E), sizeOfInt(B), sizeOfInt(C), sizeOfInt(D), sizeOfInt(F), array10(C), ref(N,I), ref(O,J), ref(P,J), ref(Q,J), ref(R,H), ref(S,H), cfg(L,R), cfg(M,O), cfg(T,M), pointer(J), sizeOfInt(I), sizeOfInt(H), array10(I).
# [Most-specific clause reduced by 6 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), ancestor(A,E), cfg(A,F), cfg(G,A), ref(B,H), ref(C,
# 	I), ref(D,H), ref(E,J), ref(F,H), cfg(B,G), cfg(C,B),
# 	cfg(D,K), cfg(E,D), cfg(F,L), cfg(K,C), cfg(M,E), pointer(E),
# 	sizeOfInt(B), sizeOfInt(C), sizeOfInt(D), sizeOfInt(F),
# 	array10(C), ref(N,H), cfg(L,N), cfg(O,M), pointer(J),
# 	sizeOfInt(I), sizeOfInt(H), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [8 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
# [Generalising bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).]
# [Generalising <bug(bad_62804_id_110_f_loop_01_c_l_32_c_12_).>]
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,D), ancestor(A,E), cfg(A,F), cfg(G,A), ref(B,H), ref(C,I), ref(D,H), ref(E,J), ref(F,H), cfg(B,G), cfg(C,B), cfg(D,K), cfg(E,D), cfg(F,L), cfg(K,C), cfg(M,E), pointer(E), sizeOfInt(B), sizeOfInt(C), sizeOfInt(D), sizeOfInt(F), array10(C), ref(N,J), ref(O,J), ref(P,J), ref(Q,H), ref(R,H), ref(S,I), cfg(L,Q), cfg(M,N), cfg(T,M), pointer(J), sizeOfInt(I), sizeOfInt(H), array10(I).
# [Most-specific clause reduced by 6 literals]
# [Most specific clause is]
#
# bug(A) :- writeToPointer(A), ancestor(A,B), ancestor(A,C), ancestor(A,
# 	D), ancestor(A,E), cfg(A,F), cfg(G,A), ref(B,H), ref(C,
# 	I), ref(D,H), ref(E,J), ref(F,H), cfg(B,G), cfg(C,B),
# 	cfg(D,K), cfg(E,D), cfg(F,L), cfg(K,C), cfg(M,E), pointer(E),
# 	sizeOfInt(B), sizeOfInt(C), sizeOfInt(D), sizeOfInt(F),
# 	array10(C), ref(N,H), cfg(L,N), cfg(O,M), pointer(J),
# 	sizeOfInt(I), sizeOfInt(H), array10(I).
#
# [C:279,300,20,0 bug(A).]
# [C:278,300,20,0 bug(A) :- writeToPointer(A).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- ancestor(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(A,B).]
# [C:278,300,20,0 bug(A) :- cfg(B,A).]
# [8 explored search nodes]
# f=279,p=300,n=20,h=0
# [No compression]
#
#
# [Total time taken 1.550s]

# %%
with open("../code/progol_input_one_bug_node.pl", "w") as f:
    f.write(script)

# %%
rule = """bug(A) :- ilp(doesnt_work), ref(doesnt_work,sad), dan(sad)."""
graph_visualisation.jupyter_display_graph(graph_visualisation.prolog_rule_to_dot(rule))

# %% [markdown]
# Use our own, or Claires, rule and tailor our background knowledge to provide it.
